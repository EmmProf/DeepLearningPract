# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy
import pandas as pd
# fix random seed for reproducibility
numpy.random.seed(7)

# %%
dataset = numpy.loadtxt('pima-indians-diabetes.data.csv',delimiter=',')

# %%
dat = pd.DataFrame(dataset)

# %%
a = round(len(dat)*0.8)
# Out:
# 614

# %%
X = dataset[:614,0:8]
Y = dataset[:614,8]

# %%
Xtes = dataset[614:,0:8]
Ytes = dataset[614:,8]

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model

# %%
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X, Y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 614/614 [==============================] - 0s 535us/step - loss: 3.8983 - acc: 0.6417
# Epoch 2/150
# 614/614 [==============================] - 0s 105us/step - loss: 1.1671 - acc: 0.5407
# Epoch 3/150
# 614/614 [==============================] - 0s 100us/step - loss: 0.7799 - acc: 0.6417
# Epoch 4/150
# 614/614 [==============================] - 0s 102us/step - loss: 0.7283 - acc: 0.6629
# Epoch 5/150
# 614/614 [==============================] - 0s 116us/step - loss: 0.7240 - acc: 0.6547
# Epoch 6/150
# 614/614 [==============================] - 0s 102us/step - loss: 0.6853 - acc: 0.6645
# Epoch 7/150
# 614/614 [==============================] - 0s 103us/step - loss: 0.6674 - acc: 0.6759
# Epoch 8/150
# 614/614 [==============================] - 0s 104us/step - loss: 0.6471 - acc: 0.6759
# Epoch 9/150
# 614/614 [==============================] - 0s 101us/step - loss: 0.6461 - acc: 0.6840
# Epoch 10/150
# ...

# %%
scores = model.evaluate(Xtes, Ytes)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 154/154 [==============================] - 0s 39us/step
#
# acc: 71.43%

# %%
print(model.metrics_names)
# Out:
# ['loss', 'acc']

# %%
scores
# Out:
# [0.5642710780942595, 0.7142857166079731]

# %%
print("\n%s: %.2f%%")
# Out:
# %s: %.2f%%

# %%
sum([y - p for p,y in zip(Ytes,[round(x[0]) for x in model.predict(Xtes)])])/len([y - p for y,p in zip(Ytes,[round(x[0]) for x in model.predict(Xtes)])])
# Out:
# -0.07792207792207792
