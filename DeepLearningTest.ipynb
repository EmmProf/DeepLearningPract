# %%
import keras
import numpy as np

# %%
data = np.loadtxt("pima-indians-diabetes.data.csv",delimiter=',')

# %%
subsample = np.random.choice(len(data),round(0.9*len(data)),replace=False)

# %%
X = data[:,:8]
Y = data[:,8]

# %%
mod = keras.Sequential()

# %%
mod.add(keras.layers.Dense(2,input_dim=8,activation='relu'))

# %%
mod.add(keras.layers.Dense(1,activation = "sigmoid"))

# %%
model.compile(loss="binary_crossentropy",optimizer="Adam",metrics=["accuracy"])

# %%
model.fit(X,Y,epochs=100,batch_size=10)
# Out:
# Epoch 1/100
# 768/768 [==============================] - 0s 131us/step - loss: 0.4940 - acc: 0.7604
# Epoch 2/100
# 768/768 [==============================] - 0s 119us/step - loss: 0.4810 - acc: 0.7813
# Epoch 3/100
# 768/768 [==============================] - 0s 108us/step - loss: 0.4735 - acc: 0.7747
# Epoch 4/100
# 768/768 [==============================] - 0s 107us/step - loss: 0.4394 - acc: 0.7904
# Epoch 5/100
# 768/768 [==============================] - 0s 105us/step - loss: 0.4585 - acc: 0.7773
# Epoch 6/100
# 768/768 [==============================] - 0s 102us/step - loss: 0.4555 - acc: 0.7799
# Epoch 7/100
# 768/768 [==============================] - 0s 107us/step - loss: 0.4752 - acc: 0.7669
# Epoch 8/100
# 768/768 [==============================] - 0s 108us/step - loss: 0.4508 - acc: 0.7930
# Epoch 9/100
# 768/768 [==============================] - 0s 107us/step - loss: 0.4399 - acc: 0.7930
# Epoch 10/100
# ...

# %%
import matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-124-0484cd13f94d> in <module>()
# ----> 1 import matplotlib
#
# ModuleNotFoundError: No module named 'matplotlib'
