# %%
import pandas as pd
# Out:
# /Users/emmanuelprofumo/Desktop/DeepLearningPract/venv/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/emmanuelprofumo/Desktop/DeepLearningPract/venv/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df = pd.read_csv('all/sales_train.csv')

# %%
encoding = df.groupby('shop_id').size()

# %%
encoding = encoding/len(df)

# %%
df["new"] = df.shop_id.map(encoding)

# %%
df
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# 5        10.01.2013               0       25     2564      349.00
# 6        02.01.2013               0       25     2565      549.00
# 7        04.01.2013               0       25     2572      239.00
# 8        11.01.2013               0       25     2572      299.00
# 9        03.01.2013               0       25     2573      299.00
# 10       03.01.2013               0       25     2574      399.00
# 11       05.01.2013               0       25     2574      399.00
# 12       07.01.2013               0       25     2574      399.00
# ...

# %%
encoding
# Out:
# shop_id
# 0     0.003357
# 1     0.001934
# 2     0.008853
# 3     0.008697
# 4     0.013026
# 5     0.013004
# 6     0.028156
# 7     0.019782
# 8     0.001162
# 9     0.001278
# 10    0.007288
# 11    0.000170
# 12    0.011817
# 13    0.006071
# 14    0.012596
# 15    0.020270
# 16    0.017962
# 17    0.007817
# 18    0.018130
# 19    0.021769
# 20    0.000610
# 21    0.019801
# 22    0.015476
# 23    0.002372
# 24    0.018064
# 25    0.063390
# 26    0.018363
# 27    0.035889
# 28    0.048447
# 29    0.016767
# 30    0.017324
# 31    0.080262
# 32    0.002707
# 33    0.001712
# 34    0.001959
# 35    0.019907
# 36    0.000104
# 37    0.013501
# 38    0.015673
# 39    0.004578
# 40    0.001450
# 41    0.014295
# 42    0.037213
# 43    0.013380
# 44    0.013465
# 45    0.012225
# 46    0.022590
# 47    0.019311
# 48    0.007361
# 49    0.005398
# 50    0.022199
# 51    0.015135
# 52    0.014818
# 53    0.018026
# 54    0.048872
# 55    0.011843
# 56    0.023698
# 57    0.039998
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
a  =LabelEncoder()

# %%
type(a.fit_transform(df.shop_id)[0])
# Out:
# numpy.int64

# %%
type(df.shop_id[0])
# Out:
# numpy.int64

# %%
a.fit
# Out:
# <bound method LabelEncoder.fit_transform of LabelEncoder()>
