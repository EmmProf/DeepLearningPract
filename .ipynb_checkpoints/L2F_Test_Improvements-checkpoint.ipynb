# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(rc={'figure.figsize':(11,8)})

# %% [markdown]
# # 1. Exploring the data

# %% [markdown]
# 1.

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
Pokemon = pd.read_csv("modelling_expert_test/pokemon.csv")

# %%
Combats = pd.read_csv("modelling_expert_test/combats.csv")

# %%
Pokemon.head()
# Out:
#    pid           Name Class 1 Class 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    1      Bulbasaur   Grass  Poison  45      49       49       65       65
# 1    2        Ivysaur   Grass  Poison  60      62       63       80       80
# 2    3       Venusaur   Grass  Poison  80      82       83      100      100
# 3    4  Mega Venusaur   Grass  Poison  80     100      123      122      120
# 4    5     Charmander    Fire     NaN  39      52       43       60       50
#
#    Speed  Legendary
# 0     45      False
# 1     60      False
# 2     80      False
# 3     80      False
# 4     65      False

# %%
Combats.head()
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0            266             298     298
# 1            702             701     701
# 2            191             668     668
# 3            237             683     683
# 4            151             231     151

# %% [markdown]
# (a)

# %%
sns.jointplot(x="Attack",y="Defense",data=Pokemon,kind="kde")

# %%
sns.jointplot(x="Attack",y="Defense",data=Pokemon)
# Out:
# /Users/emmanuelprofumo/Desktop/DeepLearningPract/venv/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x="Defense",y="Attack",data=Pokemon)
# Out:
# /Users/emmanuelprofumo/Desktop/DeepLearningPract/venv/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.violinplot(data=Pokemon[["Attack","Defense"]])
# Out:
# /Users/emmanuelprofumo/Desktop/DeepLearningPract/venv/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.violinplot(x=pd.cut(Pokemon.Attack,bins=10),y=Pokemon.Defense,
               scale="count",cut=0.2)
# Out:
# /Users/emmanuelprofumo/Desktop/DeepLearningPract/venv/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.violinplot(x=pd.cut(Pokemon.Defense,bins=10),y=Pokemon.Attack,
               scale="count",cut=0.2)
# Out:
# /Users/emmanuelprofumo/Desktop/DeepLearningPract/venv/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
Pokemon["AttackOverDefense"] = Pokemon.Attack/Pokemon.Defense

# %% [markdown]
# The two distributions seem to be relatively similar, except that "Defense" has some outliers.
# From the joint plot we can see that the smaller Attack and Defense are, the more similar they tend to be. If the Attack is higher, then it seems that there is more variability for Defense, also the distribution have more chance to have high Defense outliers when the Attack is larger. Also for strong Attacks, it seems that Attack tends to be larger than Defense and for weak Attacks Defense seems tend to be larger.

# %%
Pokemon["AttackOverDefense"] = Pokemon.Attack/Pokemon.Defense

# %%
sns.jointplot(x="Attack",y="AttackOverDefense",data=Pokemon)
# Out:
# /Users/emmanuelprofumo/Desktop/DeepLearningPract/venv/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# (b)

# %%
Pokemon.sort_values(by="AttackOverDefense",ascending=False).head(3)
# Out:
#      pid                Name  Class 1 Class 2  HP  Attack  Defense  Sp. Atk  \
# 429  430  DeoxysAttack Forme  Psychic     NaN  50     180       20      180
# 347  348            Carvanha    Water    Dark  45      90       20       65
# 19    20       Mega Beedrill      Bug  Poison  65     150       40       15
#
#      Sp. Def  Speed  Legendary  AttackOverDefense
# 429       20    150       True               9.00
# 347       20     65      False               4.50
# 19        80    145      False               3.75

# %% [markdown]
# (c)

# %%
#INDEXING ERROR IN LAST VERSION
Pokemon.loc[Combats.Winner.value_counts().index[:10] - 1]
# Out:
#      pid                Name  Class 1   Class 2   HP  Attack  Defense  \
# 162  163              Mewtwo  Psychic       NaN  106     110       90
# 153  154          Aerodactyl     Rock    Flying   80     105       65
# 437  438           Infernape     Fire  Fighting   76     104       71
# 427  428             Jirachi    Steel   Psychic  100     100      100
# 431  432  Deoxys Speed Forme  Psychic       NaN   50      95       90
# 313  314             Slaking   Normal       NaN  150     160      100
# 213  214             Murkrow     Dark    Flying   60      85       42
# 393  394          Mega Absol     Dark       NaN   65     150       60
# 248  249       Mega Houndoom     Dark      Fire   75      90       90
# 154  155     Mega Aerodactyl     Rock    Flying   80     135       85
#
#      Sp. Atk  Sp. Def  Speed  Legendary  AttackOverDefense
# 162      154       90    130       True           1.222222
# 153       60       75    130      False           1.615385
# 437      104       71    108      False           1.464789
# 427      100      100    100       True           1.000000
# 431       95       90    180       True           1.055556
# 313       95       65    100      False           1.600000
# 213       85       42     91      False           2.023810
# 393      115       60    115      False           2.500000
# 248      140       90    115      False           1.000000
# 154       70       95    150      False           1.588235

# %% [markdown]
# 2.

# %%
#Check some properties of the Class features

# %%
sum(Pokemon["Class 1"] == Pokemon["Class 2"])
# Out:
# 0

# %%
Pokemon["Class 1"].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
Pokemon["Class 2"].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
#Pokemons belonging to one class only
PokeR = Pokemon.loc[(Pokemon["Class 1"].isin(["Rock","Grass"])) ^ (Pokemon["Class 2"].isin(["Rock","Grass"]))]

# %%
PokeRock = PokeR.loc[(PokeR["Class 1"] == "Rock") | (PokeR["Class 2"] == "Rock")]

# %%
PokeGrass = PokeR.loc[(PokeR["Class 1"] == "Grass") | (PokeR["Class 2"] == "Grass")]

# %%
sns.distplot(PokeRock.Attack,kde=True,rug=True,label="Rock")
sns.distplot(PokeGrass.Attack,kde=True,rug=True,label="Grass")
# Out:
# /Users/emmanuelprofumo/Desktop/DeepLearningPract/venv/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Pokemons in the class Rock seem to have a stronger attack than the one in the class Grass. We extract some statistics for the two classes.

# %%
(PokeRock.Attack.min(),PokeRock.Attack.max())
# Out:
# (10, 165)

# %%
(PokeGrass.Attack.min(),PokeGrass.Attack.max())
# Out:
# (27, 132)

# %%
CategRock = pd.cut(PokeRock.Attack,20,)

# %%
CategGrass = pd.cut(PokeGrass.Attack,bins=CategRock.cat.categories)

# %%
len(PokeRock),len(PokeGrass)
# Out:
# (56, 93)

# %%
PokeRock.Attack.std()
# Out:
# 34.80528396964738

# %%
PokeRock.Attack.mean()
# Out:
# 91.78571428571429

# %%
PokeGrass.Attack.std()
# Out:
# 24.179644594497713

# %%
PokeGrass.Attack.mean()
# Out:
# 73.73118279569893

# %% [markdown]
# The standard deviations are roughly the same but the mean is higher for the PokeRock, we could use other descriptive statistics, and a statistical test

# %% [markdown]
# **Improvement**
#
# To check if the Professor is right we do a small experiment where we randomly pick pokemons from the two classes and compare their attack. We see that 2 times out of 3 a Rock Pokemon have stronger attacks than a Grass Pokemon, so in that sense he is not right. If we consider kind of group attacks then maybe the result would be different.

# %%
Counts = list()

#to check convergence several n values (just an example so did not do it for enough values)
for n in [10,50,100,200,500,1000,10000,50000,100000]:
    Count = 0
    for i in range(n):
        Count += (PokeGrass.Attack.sample().values[0] > PokeRock.Attack.sample().values[0])
    Counts.append(Count)

# %%
plt.scatter([10,50,100,200,500,1000,10000,50000,100000],
         np.array(Counts)/np.array([10,50,100,200,500,1000,10000,50000,100000]))

# %%
#Checking that we get 1/2 for Pokemon in the same class

# %%
Count = 0
for i in range(10000):
        Count += (PokeRock.Attack.sample().values[0] > PokeRock.Attack.sample().values[0])

Count/10000
# Out:
# 0.4813

# %%
Count = 0
for i in range(10000):
        Count += (PokeGrass.Attack.sample().values[0] > PokeGrass.Attack.sample().values[0])

Count/10000
# Out:
# 0.4855

# %% [markdown]
# ## 2. Prediction

# %% [markdown]
# ### 1. Feature preprocessing, generation

# %% [markdown]
# I start with the features of one Pokemon

# %%
#Basic preprocessing from previous steps
Pokemon = pd.read_csv("modelling_expert_test/pokemon.csv")
Combats = pd.read_csv("modelling_expert_test/combats.csv")
Pokemon["AttackOverDefense"] = Pokemon.Attack/Pokemon.Defense

# %%
#NAs
Pokemon.isna().sum()
# Out:
# pid                    0
# Name                   1
# Class 1                0
# Class 2              386
# HP                     0
# Attack                 0
# Defense                0
# Sp. Atk                0
# Sp. Def                0
# Speed                  0
# Legendary              0
# AttackOverDefense      0
# dtype: int64

# %%
#Add a category for NAs for Class 2, by prior knowledge of pokemons we assume it means Only One Class
Pokemon["Class 2"] = Pokemon["Class 2"].fillna("OneClass")

# %%
#One pokemon name is na, I name it NaN

# %%
Pokemon.Name = Pokemon.Name.fillna("NaN")

# %% [markdown]
# Name feature analysis, Concluded that maybe it is not worth it

# %%
#Also this small modif

# %%
Pokemon.Name.loc[Pokemon.Name == "DeoxysAttack Forme"] = "Deoxys Attack Forme"
# Out:
# /Users/emmanuelprofumo/Desktop/DeepLearningPract/venv/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
NotComposedName = Pokemon.Name.loc[~Pokemon.Name.str.contains(" ")]
#not composed name are unique

# %%
ComposedName = Pokemon.Name.loc[Pokemon.Name.str.contains(" ")]

# %%
Words = ComposedName.str.cat(sep=" ").split()

# %%
EvolvedPokemon = [s for s in Words if sum(NotComposedName == s) ]

# %%
OtherWords = [s for s in Words if not sum(NotComposedName == s)]

# %%
#Pokemons with Forme
FormePoke =Pokemon.Name.loc[Pokemon.Name.str.contains("Forme")]
FormePoke
# Out:
# 428          Deoxys Normal Forme
# 429          Deoxys Attack Forme
# 430         Deoxys Defense Forme
# 431           Deoxys Speed Forme
# 544       Giratina Altered Forme
# 545        Giratina Origin Forme
# 550           Shaymin Land Forme
# 551            Shaymin Sky Forme
# 702     Tornadus Incarnate Forme
# 703       Tornadus Therian Forme
# 704    Thundurus Incarnate Forme
# 705      Thundurus Therian Forme
# 708     Landorus Incarnate Forme
# 709       Landorus Therian Forme
# 713        Keldeo Ordinary Forme
# 714        Keldeo Resolute Forme
# 715          Meloetta Aria Forme
# 716     Meloetta Pirouette Forme
# 750        Aegislash Blade Forme
# 751       Aegislash Shield Forme
# 794           Zygarde Half Forme
# Name: Name, dtype: object

# %%
Formes = FormePoke.str.split().apply(lambda s:s[1])
Originals = FormePoke.str.split().apply(lambda s:s[0])

# %%
pd.Series(OtherWords).loc[~pd.Series(OtherWords).isin(Originals.append(Formes))].value_counts()
# Out:
# Mega          48
# Forme         21
# Size           8
# Gourgeist      4
# Pumpkaboo      4
# Cloak          3
# Wormadam       3
# Primal         2
# Large          2
# Darmanitan     2
# Hoopa          2
# Y              2
# Small          2
# Meowstic       2
# Average        2
# Mime           2
# Mode           2
# Super          2
# X              2
# Jr.            1
# Mr.            1
# Female         1
# Male           1
# Unbound        1
# Sandy          1
# Zen            1
# Black          1
# Trash          1
# Frost          1
# Standard       1
# Heat           1
# Confined       1
# Mow            1
# White          1
# Plant          1
# Wash           1
# Fan            1
# dtype: int64

# %% [markdown]
# Could use a categorical variable "Forme", and a binary variable "Mega"... but maybe not worth it, it does apply to a lot of pokemon, so we would do this to refine a model

# %%
#checking how much pokemon are involved in fights
Combats.First_pokemon.append(Combats.Second_pokemon).nunique(), len(Pokemon)
# Out:
# (784, 800)

# %%
#Remove Name feature, because of previous analysis
PokemonM = Pokemon.loc[:,Pokemon.columns != "Name"]

# %%
#I think there is no need to normalize because the numerical features seem to 
#have similar ranges and also from prior knowledge of pokemons, one the absolute values
#of these features are used to compute the outcome of a move in a fight (not sure)
#otherwise use sklearn.preprocessing.Normalizer

# %%
PokemonM.dtypes
# Out:
# pid                    int64
# Class 1               object
# Class 2               object
# HP                     int64
# Attack                 int64
# Defense                int64
# Sp. Atk                int64
# Sp. Def                int64
# Speed                  int64
# Legendary               bool
# AttackOverDefense    float64
# dtype: object

# %%
# Now use LabelEncoder on Categorical variables
from sklearn.preprocessing import LabelEncoder

Encoder = LabelEncoder()

PokemonM["Class 1"] = Encoder.fit_transform(PokemonM["Class 1"],)
PokemonM["Class 2"] = Encoder.fit_transform(PokemonM["Class 2"],)
# Out:
# /Users/emmanuelprofumo/Desktop/DeepLearningPract/venv/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/emmanuelprofumo/Desktop/DeepLearningPract/venv/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
#Could use a product between classes

# %% [markdown]
# Preprocessing for Fights

# %%
#Realized that preprocessing has to be done after merging
#The response variable is as "First pokemon won"
Combats["Winner"] = Combats.First_pokemon == Combats.Winner

# %%
Combats["Winner"] = Encoder.fit_transform(Combats["Winner"],)

# %%
#From prior knowledge on pokemons most of the characteristics of pokemon can explain the 
#outcome of a fight but in case there are some other that we do not know, we can keep
#the id of the two pokemons for now, then we will select variables

# %%
Combats.First_pokemon = Encoder.fit_transform(Combats.First_pokemon,)
Combats.Second_pokemon = Encoder.fit_transform(Combats.Second_pokemon,)

# %% [markdown]
# Now let's join the dataframes together and create new crossed features

# %%
ColNames = PokemonM.columns.values.copy()

# %%
PokemonFirst = PokemonM.copy()

PokemonFirst.columns.values[0] = "First_pokemon"

PokemonFirst.columns.values[1:] = "First" + ColNames[1:]

# %%
CombatsM = pd.merge(Combats,PokemonFirst,on="First_pokemon",sort=False)

# %%
CombatsM.Winner.sum()
# Out:
# 23589

# %%
ColNames
# Out:
# array(['pid', 'Class 1', 'Class 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Legendary', 'AttackOverDefense'], dtype=object)

# %%
PokemonM.columns
# Out:
# Index(['First_pokemon', 'FirstClass 1', 'FirstClass 2', 'FirstHP',
#        'FirstAttack', 'FirstDefense', 'FirstSp. Atk', 'FirstSp. Def',
#        'FirstSpeed', 'FirstLegendary', 'FirstAttackOverDefense'],
#       dtype='object')

# %%
PokemonSecond = PokemonM.copy()

PokemonSecond.columns.values[0] = "Second_pokemon"

PokemonSecond.columns.values[1:] = "Second" + ColNames[1:]

# %%
CombatsMM = pd.merge(CombatsM,PokemonSecond,on="Second_pokemon",sort=False)

# %%
CombatsMM.dtypes
# Out:
# First_pokemon                int64
# Second_pokemon               int64
# Winner                       int64
# FirstClass 1                 int64
# FirstClass 2                 int64
# FirstHP                      int64
# FirstAttack                  int64
# FirstDefense                 int64
# FirstSp. Atk                 int64
# FirstSp. Def                 int64
# FirstSpeed                   int64
# FirstLegendary                bool
# FirstAttackOverDefense     float64
# SecondClass 1                int64
# SecondClass 2                int64
# SecondHP                     int64
# SecondAttack                 int64
# SecondDefense                int64
# SecondSp. Atk                int64
# SecondSp. Def                int64
# SecondSpeed                  int64
# SecondLegendary               bool
# SecondAttackOverDefense    float64
# dtype: object

# %%
CombatsMM.head()
# Out:
#    First_pokemon  Second_pokemon  Winner  FirstClass 1  FirstClass 2  FirstHP  \
# 0            256             288       0             5            13       35
# 1             68             288       0            17             5       90
# 2            362             288       0            10             2       80
# 3            523             288       1            11            13       65
# 4            357             288       1            14            13       60
#
#    FirstAttack  FirstDefense  FirstSp. Atk  FirstSp. Def       ...         \
# 0           35            35            35            35       ...
# 1           95            95            70            90       ...
# 2          100            80            80            80       ...
# 3           60           110           130            95       ...
# 4           25            35            70            80       ...
#
#    SecondSp. Atk  SecondSp. Def  SecondSpeed  SecondLegendary  \
# 0             50             61          100            False
# 1             50             61          100            False
# 2             50             61          100            False
# 3             50             61          100            False
# 4             50             61          100            False
#
#    SecondAttackOverDefense  AttackDiff  DefenseDiff  HPDiff  SpeedDiff  \
# 0                 1.147541         -35          -26     -43        -65
# 1                 1.147541          25           34      12        -30
# 2                 1.147541          30           19       2          0
# 3                 1.147541         -10           49     -13        -35
# 4                 1.147541         -45          -26     -18        -40
#
#    NbMatchingClass
# 0                1
# 1                0
# 2                0
# 3                1
# 4                1
#
# [5 rows x 28 columns]

# %%
len(CombatsMM),len(Combats),sum(CombatsMM.Winner),sum(Combats.Winner)
# Out:
# (49867, 50000, 23551, 23601)

# %%
#we could do this for every numerical feature (also ratio)

CombatsMM["AttackDiff"] = CombatsMM.FirstAttack - CombatsMM.SecondAttack
CombatsMM["DefenseDiff"] = CombatsMM.FirstDefense -CombatsMM.SecondDefense

# %%
CombatsMM["HPDiff"] = CombatsMM.FirstHP - CombatsMM.SecondHP
CombatsMM["SpeedDiff"] = CombatsMM.FirstSpeed - CombatsMM.SecondSpeed

# %%
#Are Pokemons of different classes
CombatsMM["NbMatchingClass"] = 1*(CombatsMM["FirstClass 1"] == CombatsMM["SecondClass 1"]) + 1*(CombatsMM["FirstClass 2"] == CombatsMM["SecondClass 2"])

# %%
CombatsMM.dtypes
# Out:
# First_pokemon                int64
# Second_pokemon               int64
# Winner                       int64
# FirstClass 1                 int64
# FirstClass 2                 int64
# FirstHP                      int64
# FirstAttack                  int64
# FirstDefense                 int64
# FirstSp. Atk                 int64
# FirstSp. Def                 int64
# FirstSpeed                   int64
# FirstLegendary                bool
# FirstAttackOverDefense     float64
# SecondClass 1                int64
# SecondClass 2                int64
# SecondHP                     int64
# SecondAttack                 int64
# SecondDefense                int64
# SecondSp. Atk                int64
# SecondSp. Def                int64
# SecondSpeed                  int64
# SecondLegendary               bool
# SecondAttackOverDefense    float64
# AttackDiff                   int64
# DefenseDiff                  int64
# HPDiff                       int64
# SpeedDiff                    int64
# NbMatchingClass              int64
# dtype: object

# %%
CombatsMM["FirstClass 1"] = Encoder.fit_transform(CombatsMM["FirstClass 1"],)
CombatsMM["FirstClass 2"] = Encoder.fit_transform(CombatsMM["FirstClass 2"],)
CombatsMM["SecondClass 1"] = Encoder.fit_transform(CombatsMM["SecondClass 1"],)
CombatsMM["SecondClass 2"] = Encoder.fit_transform(CombatsMM["SecondClass 2"],)

# %% [markdown]
# ### 2. Training different models and evaluating their performances
#
# While trying out some models we can look at the feature importance

# %% [markdown]
# Start with Tree based model

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold

# %% [markdown]
# With all features first, RandomForest and GBDT

# %%
#No class imbalance
sum(CombatsMM.Winner)/len(CombatsMM)
# Out:
# 0.4722762548378687

# %%
X = CombatsMM.loc[:,CombatsMM.columns != "Winner"]
y = CombatsMM.Winner

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=23,test_size = 0.2)

# %% [markdown]
# RandomForest

# %%
RF = RandomForestClassifier(min_samples_split=5,max_depth=12,
                            n_estimators=50,random_state=45)

RF.fit(X_train,y_train)

PredsRFin = RF.predict(X_train)
PredsRFout = RF.predict(X_test)

#No class imbalance, so accuracy is fine
1 - sum(np.abs(PredsRFin - y_train))/len(y_train),1 - sum(np.abs(PredsRFout - y_test))/len(y_test)
# Out:
# (0.8569172536535232, 0.7448365750952477)

# %%
RF.score(X_test,y_test)
# Out:
# 0.7448365750952477

# %%
#CV, 5-Fold
CVScores = cross_val_score(X=X,y=y,
                           cv=StratifiedKFold(n_splits=5,shuffle=True,random_state=32),
                           estimator=RF)

# %%
CVScores.mean(),CVScores.std()
# Out:
# (0.7455832602663783, 0.0038488183796635414)

# %%
sns.barplot(X_train.columns,RF.feature_importances_)

# %%
X_train.columns.values[RF.feature_importances_ > 0.04]
# Out:
# array(['First_pokemon', 'Second_pokemon', 'FirstHP', 'FirstAttack',
#        'FirstDefense', 'FirstSp. Atk', 'FirstSp. Def', 'FirstSpeed',
#        'FirstAttackOverDefense', 'SecondAttackOverDefense', 'SpeedDiff'],
#       dtype=object)

# %% [markdown]
# GBDT

# %%
GB = GradientBoostingClassifier(min_samples_split=5,max_leaf_nodes=8,
                                n_estimators=1000,random_state=5,
                                verbose=True)

GB.fit(X_train,y_train)

PredsGBin = GB.predict(X_train)
PredsGBout = GB.predict(X_test)

#Accuracy 
1 - sum(np.abs(PredsGBin - y_train))/len(y_train),1 - sum(np.abs(PredsGBout - y_test))/len(y_test)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.3791            1.08m
#          2           1.3754            1.06m
#          3           1.3706           59.26s
#          4           1.3665            1.01m
#          5           1.3638           59.07s
#          6           1.3597           56.66s
#          7           1.3566           56.74s
#          8           1.3536           55.68s
#          9           1.3511           54.48s
#         10           1.3479           53.86s
#         20           1.3212           49.10s
#         30           1.2984           47.88s
#         40           1.2803           45.61s
#         50           1.2600           44.43s
#         60           1.2447           42.84s
#         70           1.2292           41.79s
#         80           1.2155           41.14s
#         90           1.2014           40.37s
#        100           1.1899           39.56s
#        200           1.0878           33.60s
#        300           1.0140           29.26s
#        400           0.9608           25.14s
#        500           0.9167           20.62s
#        600           0.8800           16.33s
#        700           0.8505           12.11s
#        800           0.8245            8.00s
#        900           0.8020            3.97s
#       1000           0.7820            0.00s
# (0.8674203494347379, 0.8302586725486264)

# %%
#CV, 5-Fold
CVScores0 = CVScores = cross_val_score(X=X,y=y,cv=StratifiedKFold(n_splits=5,shuffle=True,
                                                      random_state=32),
                           estimator=GB,n_jobs=2)
CVScores0.mean(),CVScores0.std()
# Out:
# (0.834981101605915, 0.004148375262975193)

# %%
np.round(CVScores0.mean(),2),CVScores0.std()
# Out:
# (0.83, 0.004148375262975193)

# %%
sns.barplot(X_train.columns,GB.feature_importances_)

# %%
sel = X_train.columns.values[GB.feature_importances_ < 0.12]
sel
# Out:
# array(['FirstClass 1', 'FirstClass 2', 'FirstHP', 'FirstAttack',
#        'FirstDefense', 'FirstSp. Atk', 'FirstSp. Def', 'FirstSpeed',
#        'FirstLegendary', 'FirstAttackOverDefense', 'SecondClass 1',
#        'SecondClass 2', 'SecondHP', 'SecondAttack', 'SecondDefense',
#        'SecondSp. Atk', 'SecondSp. Def', 'SecondSpeed', 'SecondLegendary',
#        'SecondAttackOverDefense', 'AttackDiff', 'DefenseDiff', 'HPDiff',
#        'SpeedDiff', 'NbMatchingClass'], dtype=object)

# %% [markdown]
# It seems that second and first pokemons are quite important.
#
# small interactive plot next

# %%
import ipywidgets
import warnings
warnings.filterwarnings('ignore')

# %%
@ipywidgets.interact(Name = Pokemon.Name,l=(1,20))
def displai(Name=Pokemon.Name[0]):
    PokemonID = Pokemon.loc[Pokemon.Name== Name,"pid"].values[0]
    SubCombats = CombatsMM.loc[CombatsMM.First_pokemon == PokemonID]
    SubCombats["SecondName"] = CombatsMM.Second_pokemon.map(pd.Series(Pokemon.Name,
                                                                      index=Pokemon.pid))
    SubCombats["Outcome"] = SubCombats.Winner.map(pd.Series(["Lost","Won"],index=[0,1]))
    sns.scatterplot(x="Outcome",y="SecondName",data=SubCombats)
# Out:
# interactive(children=(Dropdown(description='Name', options=('Bulbasaur', 'Ivysaur', 'Venusaur', 'Mega Venusaur…

# %% [markdown]
# Using the IDs of the two pokemons is like reading in a 2D grid of historical fights between pokemons and saying who won or lose the last fight/majority of fights
#
# Let's try without these features

# %%
sel
# Out:
# array(['FirstClass 1', 'FirstClass 2', 'FirstHP', 'FirstAttack',
#        'FirstDefense', 'FirstSp. Atk', 'FirstSp. Def', 'FirstSpeed',
#        'FirstLegendary', 'FirstAttackOverDefense', 'SecondClass 1',
#        'SecondClass 2', 'SecondHP', 'SecondAttack', 'SecondDefense',
#        'SecondSp. Atk', 'SecondSp. Def', 'SecondSpeed', 'SecondLegendary',
#        'SecondAttackOverDefense', 'AttackDiff', 'DefenseDiff', 'HPDiff',
#        'SpeedDiff', 'NbMatchingClass'], dtype=object)

# %%
X = CombatsMM.loc[:,sel]
y = CombatsMM.Winner

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=23,test_size = 0.2)

# %%
RF1 = RandomForestClassifier(min_samples_split=5,max_depth=12,
                            n_estimators=50,random_state=45)

RF1.fit(X_train,y_train)

PredsRFin = RF1.predict(X_train)
PredsRFout = RF1.predict(X_test)

#No class imbalance, so accuracy is fine
1 - sum(np.abs(PredsRFin - y_train))/len(y_train),1 - sum(np.abs(PredsRFout - y_test))/len(y_test)
# Out:
# (0.8446594640663776, 0.7394224984960898)

# %%
RF1.score(X_test,y_test),RF1.score(X_train,y_train)
# Out:
# (0.7394224984960899, 0.8446594640663776)

# %%
#CV, 5-Fold
CVScores = cross_val_score(X=X,y=y,cv=StratifiedKFold(n_splits=5,shuffle=True,
                                                      random_state=32),
                           estimator=RF1)
CVScores.mean(),CVScores.std()
# Out:
# (0.7345741170332831, 0.0038825191925702983)

# %%
sns.barplot(X_train.columns,RF1.feature_importances_)

# %%
X_train.columns.values[RF1.feature_importances_ > 0.04]
# Out:
# array(['FirstClass 1', 'FirstHP', 'FirstAttack', 'FirstDefense',
#        'FirstSp. Atk', 'FirstSp. Def', 'FirstSpeed',
#        'FirstAttackOverDefense', 'SecondSp. Atk', 'SecondSp. Def',
#        'SecondSpeed', 'SecondAttackOverDefense', 'DefenseDiff',
#        'SpeedDiff'], dtype=object)

# %% [markdown]
# GBDT

# %%
GB1 = GradientBoostingClassifier(min_samples_split=5,max_leaf_nodes=10,
                                n_estimators=1000,random_state=5,
                                verbose=True)

GB1.fit(X_train,y_train)

PredsGBin = GB1.predict(X_train)
PredsGBout = GB1.predict(X_test)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.3794            1.06m
#          2           1.3758           59.39s
#          3           1.3721           58.48s
#          4           1.3687           58.31s
#          5           1.3654           57.79s
#          6           1.3619           56.76s
#          7           1.3589           57.09s
#          8           1.3560           56.65s
#          9           1.3534           56.45s
#         10           1.3501           55.17s
#         20           1.3230           49.79s
#         30           1.3001           49.33s
#         40           1.2803           47.78s
#         50           1.2632           45.42s
#         60           1.2462           44.00s
#         70           1.2296           43.00s
#         80           1.2121           42.57s
#         90           1.1984           41.71s
#        100           1.1864           40.66s
#        200           1.0763           35.00s
#        300           1.0012           30.24s
#        400           0.9475           25.76s
#        500           0.9091           21.14s
#        600           0.8738           16.72s
#        700           0.8424           12.45s
#        800           0.8149            8.29s
#        900           0.7917            4.11s
#       1000           0.7701            0.00s

# %%
#Accuracy 
1 - sum(np.abs(PredsGBin - y_train))/len(y_train),1 - sum(np.abs(PredsGBout - y_test))/len(y_test)
# Out:
# (0.8698518537086707, 0.8289552837377181)

# %%
np.round(GB1.score(X_test,y_test),2),np.round(GB1.score(X_train,y_train),2)
# Out:
# (0.83, 0.87)

# %%
#CV, 5-Fold
CVScores2 = cross_val_score(X=X,y=y,cv=StratifiedKFold(n_splits=5,shuffle=True,
                                                      random_state=32),
                           estimator=GB1,n_jobs=2)
CVScores2.mean(),CVScores.std()
# Out:
# (0.8289047998518304, 0.0038825191925702983)

# %%
CVScores2
# Out:
# array([0.83107769, 0.82943949, 0.82793543, 0.82713326, 0.82893813])

# %%
np.round(CVScores2.mean(),2),CVScores2.std()
# Out:
# (0.83, 0.0013480735534209265)

# %%
sns.barplot(X_train.columns,GB1.feature_importances_)

# %%
sel = X_train.columns.values[GB1.feature_importances_ > 0.062]
sel
# Out:
# array(['FirstHP', 'FirstSpeed', 'FirstAttackOverDefense',
#        'SecondAttackOverDefense'], dtype=object)

# %% [markdown]
# It seems that without information on the id of the pokemon the model has similar performances

# %% [markdown]
# Let's try now with four features only

# %%
X = CombatsMM.loc[:,sel]
y = CombatsMM.Winner

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=23,test_size = 0.2)

RF2 = RandomForestClassifier(min_samples_split=5,max_depth=12,
                            n_estimators=50,random_state=45)

RF2.fit(X_train,y_train)

PredsRFin = RF2.predict(X_train)
PredsRFout = RF2.predict(X_test)

#No class imbalance, so accuracy is fine
1 - sum(np.abs(PredsRFin - y_train))/len(y_train),1 - sum(np.abs(PredsRFout - y_test))/len(y_test)

RF2.score(X_train,y_train),RF2.score(X_test,y_test)
# Out:
# (0.753891660191011, 0.7049328253458993)

# %%
#CV, 5-Fold
CVScores3 = cross_val_score(X=X,y=y,cv=StratifiedKFold(n_splits=5,shuffle=True,
                                                      random_state=32),
                           estimator=RF2)

# %%
CVScores3.mean(),CVScores3.std()
# Out:
# (0.6934045029348664, 0.0020657152725407327)

# %%
sns.barplot(X_train.columns,RF1.feature_importances_)

X_train.columns.values[RF1.feature_importances_ > 0.04]

# %% [markdown]
# GBDT

# %%
GB2 = GradientBoostingClassifier(min_samples_split=5,max_leaf_nodes=10,
                                n_estimators=1000,random_state=5,
                                verbose=True)

GB2.fit(X_train,y_train)

PredsGBin = GB2.predict(X_train)
PredsGBout = GB2.predict(X_test)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.3798           14.19s
#          2           1.3767           13.50s
#          3           1.3729           13.72s
#          4           1.3704           13.51s
#          5           1.3673           14.37s
#          6           1.3647           14.32s
#          7           1.3627           13.73s
#          8           1.3601           13.73s
#          9           1.3569           13.70s
#         10           1.3551           13.34s
#         20           1.3375           12.73s
#         30           1.3231           12.48s
#         40           1.3116           12.16s
#         50           1.2989           11.91s
#         60           1.2888           11.80s
#         70           1.2783           11.58s
#         80           1.2694           11.20s
#         90           1.2611           10.92s
#        100           1.2526           11.09s
#        200           1.1908            9.74s
#        300           1.1449            8.29s
#        400           1.1094            7.00s
#        500           1.0777            5.80s
#        600           1.0512            4.57s
#        700           1.0316            3.39s
#        800           1.0126            2.24s
#        900           0.9943            1.11s
#       1000           0.9796            0.00s

# %%
#Accuracy 
np.round(GB2.score(X_test,y_test),2),np.round(GB2.score(X_train,y_train),2)
# Out:
# (0.76, 0.78)

# %%
#CV, 5-Fold
CVScores4 = cross_val_score(X=X,y=y,cv=StratifiedKFold(n_splits=5,shuffle=True,
                                                      random_state=32),
                           estimator=GB2,n_jobs=2)
CVScores4.mean(),CVScores4.std()
# Out:
# (0.7547476311353939, 0.002220135879248139)

# %%
np.round(CVScores4.mean(),2),CVScores4.std()
# Out:
# (0.75, 0.002220135879248139)

# %%
sns.barplot(X_train.columns,GB2.feature_importances_)

# %% [markdown]
# We loose some accuracy using just this four features
#
# Let's try a GBDT with a bit more features

# %%
sel = np.array(['FirstClass 1', 'FirstHP', 'FirstAttack', 'FirstDefense',
       'FirstSp. Atk', 'FirstSp. Def', 'FirstSpeed',
       'FirstAttackOverDefense', 'SecondHP', 'SecondAttack',
       'SecondDefense', 'SecondSp. Atk', 'SecondSp. Def', 'SecondSpeed',
       'SecondAttackOverDefense'])
sel
# Out:
# array(['FirstClass 1', 'FirstHP', 'FirstAttack', 'FirstDefense',
#        'FirstSp. Atk', 'FirstSp. Def', 'FirstSpeed',
#        'FirstAttackOverDefense', 'SecondHP', 'SecondAttack',
#        'SecondDefense', 'SecondSp. Atk', 'SecondSp. Def', 'SecondSpeed',
#        'SecondAttackOverDefense'], dtype='<U23')

# %%
X = CombatsMM.loc[:,sel]
y = CombatsMM.Winner

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=23,test_size = 0.2)

# %%
GB3 = GradientBoostingClassifier(min_samples_split=5,max_leaf_nodes=10,
                                n_estimators=1000,random_state=5,
                                verbose=True)

GB3.fit(X_train,y_train)

# %%
PredsGBin = GB3.predict(X_train)
PredsGBout = GB3.predict(X_test)

# %%
#Accuracy 
np.round(GB3.score(X_test,y_test),2),np.round(GB3.score(X_train,y_train),2)
# Out:
# (0.83, 0.86)

# %%
#CV, 5-Fold
CVScores5 = cross_val_score(X=X,y=y,cv=StratifiedKFold(n_splits=5,shuffle=True),
                           estimator=GB3,n_jobs=2)

# %%
np.round(CVScores5.mean(),2),CVScores5.std()
#really low std, might be a problem with the splitter used for the cv...
# Out:
# (0.83, 0.0020743323224178506)

# %%
sns.barplot(X_train.columns,GB3.feature_importances_)

# %% [markdown]
# Pretty much the same accuracy with these features

# %%
sel = np.array( ['FirstHP', 'FirstAttack', 'FirstDefense',
       'FirstSp. Atk', 'FirstSp. Def', 'FirstSpeed',
       'FirstAttackOverDefense', 'SecondHP', 'SecondAttack',
       'SecondDefense', 'SecondSp. Atk', 'SecondSp. Def', 'SecondSpeed',
       'SecondAttackOverDefense'])

# %% [markdown]
# Let's do logistic regression with the selected variables

# %%
from sklearn.linear_model import LogisticRegression

# %%
X = CombatsMM.loc[:,sel]
y = CombatsMM.Winner

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=23,test_size = 0.2)

# %%
len(X_test),len(X_train),sum(y_train)
# Out:
# (9974, 39893, 18929)

# %%
LogReg = LogisticRegression(random_state=43,C=0.1)

# %%
LogReg.fit(X_train,y_train)
# Out:
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=43, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
#Accuracy 
np.round(LogReg.score(X_test,y_test),2),np.round(LogReg.score(X_train,y_train),2)
# Out:
# (0.55, 0.55)

# %%
PredsRFin = LogReg.predict(X_train)
PredRFout = LogReg.predict(X_test)

#No class imbalance, so accuracy is fine
1 - sum(np.abs(PredsRFin - y_train))/len(y_train),1 - sum(np.abs(PredsRFout - y_test))/len(y_test)
# Out:
# (0.5471385957436141, 0.7049328253458993)

# %%
#CV, 5-Fold
CVScores5 = cross_val_score(X=X,y=y,cv=StratifiedKFold(n_splits=5,shuffle=True),
                           estimator=LogReg,n_jobs=2)

# %%
np.round(CVScores5.mean(),2),CVScores5.std()
# Out:
# (0.55, 0.003338674641876304)

# %%
sns.barplot(X_train.columns,LogReg.coef_[0])

# %%
sel = X_train.columns.values[np.abs(LogReg.coef_[0])> 0.04]
sel
# Out:
# array(['FirstAttackOverDefense', 'SecondAttackOverDefense'], dtype=object)

# %% [markdown]
# Trying with just the two features above

# %%
X = CombatsMM.loc[:,sel]
y = CombatsMM.Winner

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=23,test_size = 0.2)

len(X_test),len(X_train),sum(y_train)
# Out:
# (9974, 39893, 18929)

# %%
LogReg = LogisticRegression(random_state=34)

LogReg.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=34, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
#Accuracy 
np.round(LogReg.score(X_test,y_test),2),np.round(LogReg.score(X_train,y_train),2)
# Out:
# (0.54, 0.53)

# %%
PredsRFin = LogReg.predict(X_train)
PredRFout = LogReg.predict(X_test)

#No class imbalance, so accuracy is fine
1 - sum(np.abs(PredsRFin - y_train))/len(y_train),1 - sum(np.abs(PredsRFout - y_test))/len(y_test)
# Out:
# (0.5291153836512672, 0.7049328253458993)

# %%
#CV, 5-Fold
CVScores5 = cross_val_score(X=X,y=y,cv=StratifiedKFold(n_splits=5,shuffle=True),
                           estimator=LogReg,n_jobs=2)

# %%
np.round(CVScores5.mean(),2),CVScores5.std()
#really low std, might be a problem with the splitter used for the cv...
# Out:
# (0.53, 0.00038247511878082)

# %%
sns.barplot(X_train.columns,LogReg.coef_[0])

# %% [markdown]
# it seems that even if we put all features the logistic regression perfomances stay the same
# Next I try with all the features, maybe one sould use OneHotEncoder for some features, not sure how the LabelEncoder is handled by logistic regression (One hot makes sense, not sure if LogisticRegression handles this internally)

# %%
X = CombatsMM.loc[:,CombatsMM.columns != "Winner"]
y = CombatsMM.Winner

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=23,test_size = 0.2)

# %%
len(X_test),len(X_train),sum(y_train)
# Out:
# (9974, 39893, 18929)

# %%
LogReg = LogisticRegression(random_state=34)

LogReg.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=34, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
#Accuracy 
np.round(LogReg.score(X_test,y_test),2),np.round(LogReg.score(X_train,y_train),2)
# Out:
# (0.56, 0.55)

# %%
PredsRFin = LogReg.predict(X_train)
PredRFout = LogReg.predict(X_test)

#No class imbalance, so accuracy is fine
1 - sum(np.abs(PredsRFin - y_train))/len(y_train),1 - sum(np.abs(PredsRFout - y_test))/len(y_test)
# Out:
# (0.553380292281854, 0.7049328253458993)

# %%
#CV, 5-Fold
CVScores5 = cross_val_score(X=X,y=y,cv=StratifiedKFold(n_splits=5,shuffle=True),
                           estimator=LogReg,n_jobs=2)

# %%
np.round(CVScores5.mean(),2),CVScores5.std()
# Out:
# (0.55, 0.003338674641876304)

# %%
sns.barplot(X_train.columns,LogReg.coef_[0])

# %% [markdown]
# This does not look so good, maybe we should do better feature engineering, e.g. combining somehow HPs, Speeds,Attacks and Defense...
#
# The gradient booosting tree yields the better results

# %% [markdown]
# Next I train some MLPs on numerical features but the results were not so good

# %%
from sklearn.neural_network import MLPClassifier

# %%
sel = np.array( ['FirstHP', 'FirstAttack', 'FirstDefense',
       'FirstSp. Atk', 'FirstSp. Def', 'FirstSpeed',
       'FirstAttackOverDefense', 'SecondHP', 'SecondAttack',
       'SecondDefense', 'SecondSp. Atk', 'SecondSp. Def', 'SecondSpeed',
       'SecondAttackOverDefense'])

# %%
X = CombatsMM.loc[:,sel]
y = CombatsMM.Winner

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=23,test_size = 0.2)

# %%
MLP = MLPClassifier(activation="identity",
                    hidden_layer_sizes=(1000,50,25,1),
                    verbose=True)

# %%
MLP.fit(X_train,y_train)
# Out:
# Iteration 1, loss = 1.58460315
# Iteration 2, loss = 0.76383115
# Iteration 3, loss = 0.73135096
# Iteration 4, loss = 0.71977680
# Iteration 5, loss = 0.70717929
# Iteration 6, loss = 0.69984032
# Iteration 7, loss = 0.70028311
# Iteration 8, loss = 0.69642916
# Iteration 9, loss = 0.69491171
# Iteration 10, loss = 0.69171166
# Iteration 11, loss = 0.69244728
# Iteration 12, loss = 0.69086935
# Iteration 13, loss = 0.69108176
# Iteration 14, loss = 0.68984448
# Iteration 15, loss = 0.68874767
# Iteration 16, loss = 0.68853396
# Iteration 17, loss = 0.69031333
# Iteration 18, loss = 0.69050777
# Iteration 19, loss = 0.69014778
# Iteration 20, loss = 0.68860069
# Iteration 21, loss = 0.68770828
# Iteration 22, loss = 0.68797385
# Iteration 23, loss = 0.68978592
# Iteration 24, loss = 0.68796009
# Iteration 25, loss = 0.68776767
# Iteration 26, loss = 0.68813693
# Iteration 27, loss = 0.68894852
# Iteration 28, loss = 0.68834394
# Iteration 29, loss = 0.68758457
# Iteration 30, loss = 0.68783991
# Iteration 31, loss = 0.68959907
# Iteration 32, loss = 0.68913961
# Iteration 33, loss = 0.68717246
# Iteration 34, loss = 0.68772316
# Iteration 35, loss = 0.68872723
# Iteration 36, loss = 0.68731174
# Iteration 37, loss = 0.68807871
# Iteration 38, loss = 0.68745709
# Iteration 39, loss = 0.68814299
# Iteration 40, loss = 0.68775186
# Iteration 41, loss = 0.68732159
# Iteration 42, loss = 0.68791991
# Iteration 43, loss = 0.68769478
# Iteration 44, loss = 0.68700852
# Iteration 45, loss = 0.68789447
# Iteration 46, loss = 0.68762878
# Iteration 47, loss = 0.68714299
# Iteration 48, loss = 0.68775510
# Iteration 49, loss = 0.68678238
# Iteration 50, loss = 0.68690465
# Iteration 51, loss = 0.68663788
# Iteration 52, loss = 0.68766123
# Iteration 53, loss = 0.68743572
# Iteration 54, loss = 0.68650538
# Iteration 55, loss = 0.68658267
# Iteration 56, loss = 0.68688614
# Iteration 57, loss = 0.68651724
# Iteration 58, loss = 0.68648091
# Iteration 59, loss = 0.68644364
# Iteration 60, loss = 0.68655394
# Iteration 61, loss = 0.68673946
# Iteration 62, loss = 0.68618375
# Iteration 63, loss = 0.68618072
# Iteration 64, loss = 0.68628176
# Iteration 65, loss = 0.68658686
# Iteration 66, loss = 0.68627309
# Iteration 67, loss = 0.68599369
# Iteration 68, loss = 0.68600501
# Iteration 69, loss = 0.68591114
# Iteration 70, loss = 0.68607054
# Iteration 71, loss = 0.68595531
# Iteration 72, loss = 0.68617456
# Iteration 73, loss = 0.68611982
# Iteration 74, loss = 0.68579014
# Iteration 75, loss = 0.68575955
# Iteration 76, loss = 0.68566955
# Iteration 77, loss = 0.68569349
# Iteration 78, loss = 0.68585319
# Iteration 79, loss = 0.68565451
# Iteration 80, loss = 0.68603421
# Iteration 81, loss = 0.68590127
# Iteration 82, loss = 0.68576673
# Iteration 83, loss = 0.68597812
# Iteration 84, loss = 0.68579526
# Iteration 85, loss = 0.68546237
# Iteration 86, loss = 0.68584826
# Iteration 87, loss = 0.68552991
# Iteration 88, loss = 0.68546302
# Iteration 89, loss = 0.68566662
# Iteration 90, loss = 0.68543291
# Iteration 91, loss = 0.68540715
# Iteration 92, loss = 0.68552339
# Iteration 93, loss = 0.68567337
# Iteration 94, loss = 0.68583695
# MLPClassifier(activation='identity', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(1000, 50, 25, 1), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#        random_state=None, shuffle=True, solver='adam', tol=0.0001,
#        validation_fraction=0.1, verbose=True, warm_start=False)

# %%
MLP.score(X_test,y_test)
# Out:
# 0.6276318427912573

# %%
pd.Series(MLP.predict(X_test))
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       1
# 5       1
# 6       1
# 7       0
# 8       1
# 9       1
# 10      1
# 11      1
# 12      0
# 13      0
# 14      0
# 15      0
# 16      0
# 17      1
# 18      1
# 19      0
# 20      0
# 21      0
# 22      1
# 23      0
# 24      0
# 25      1
# 26      0
# 27      0
# 28      0
# 29      1
#        ..
# 9944    0
# 9945    0
# 9946    1
# 9947    1
# 9948    1
# 9949    1
# 9950    0
# 9951    1
# 9952    0
# 9953    1
# 9954    1
# 9955    1
# 9956    0
# 9957    0
# 9958    1
# 9959    0
# 9960    0
# 9961    1
# 9962    0
# 9963    1
# 9964    1
# 9965    0
# 9966    0
# 9967    0
# 9968    1
# 9969    1
# 9970    0
# 9971    0
# 9972    0
# 9973    1
# Length: 9974, dtype: int64

# %% [markdown]
# With Keras to have more control on architecture

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import Callback

# %%
# Credit to Piotr Migdal, package livelossplot, to visualize loss during training
from IPython.display import clear_output
from IPython.display import clear_output

class PlotLearning(Callback):
    def on_train_begin(self, logs={}):
        self.i = 0
        self.x = []
        self.losses = []
        self.val_losses = []
        self.acc = []
        self.val_acc = []
        self.fig = plt.figure()
        
        self.logs = []

    def on_epoch_end(self, epoch, logs={}):
        
        self.logs.append(logs)
        self.x.append(self.i)
        self.losses.append(logs.get('loss'))
        self.val_losses.append(logs.get('val_loss'))
        self.acc.append(logs.get('acc'))
        self.val_acc.append(logs.get('val_acc'))
        self.i += 1
        f, (ax1, ax2) = plt.subplots(1, 2, sharex=True)
        
        clear_output(wait=True)
        
        ax1.set_yscale('log')
        ax1.plot(self.x, self.losses, label="loss")
        ax1.plot(self.x, self.val_losses, label="val_loss")
        ax1.legend()
        
        ax2.plot(self.x, self.acc, label="accuracy")
        ax2.plot(self.x, self.val_acc, label="validation accuracy")
        ax2.legend()
        
        plt.show();
        
plot = PlotLearning()

# %%
MLP = Sequential()

MLP.add(Dense(input_shape=(14,),activation="relu",units=50))
MLP.add(Dropout(0.2))
MLP.add(Dense(activation="relu",units=25))
MLP.add(Dense(activation="sigmoid",units=1))
MLP.compile(loss="binary_crossentropy",optimizer="adam",
            metrics=["accuracy"])

# %%
MLP.fit(X_train,y_train,batch_size=128,
        validation_data=(X_test, y_test),
        callbacks=[plot],
        verbose=0,
        epochs=100)

# %% [markdown]
# I also tried to fit a Decision tree but the results are not so good (overfitting)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
X = CombatsMM.loc[:,CombatsMM.columns != "Winner"]
y = CombatsMM.Winner

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=23,test_size = 0.2)

# %%
len(X_test),len(X_train),sum(y_train)
# Out:
# (9974, 39893, 18929)

# %%
TR = DecisionTreeClassifier()

TR.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=4, max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
#Accuracy 
np.round(TR.score(X_test,y_test),2),np.round(TR.score(X_train,y_train),2)
# Out:
# (0.65, 1.0)

# %%
PredsRFin = LogReg.predict(X_train)
PredRFout = LogReg.predict(X_test)

# %%
#No class imbalance, so accuracy is fine
1 - sum(np.abs(PredsRFin - y_train))/len(y_train),1 - sum(np.abs(PredsRFout - y_test))/len(y_test)
# Out:
# (0.553380292281854, 0.7049328253458993)

# %%
#CV, 5-Fold
CVScores5 = cross_val_score(X=X,y=y,cv=StratifiedKFold(n_splits=5,shuffle=True),
                           estimator=LogReg,n_jobs=2)

# %%
np.round(CVScores5.mean(),2),CVScores5.std()
# Out:
# (0.88, 0.0033109020261634743)

# %% [markdown]
# Finally let's try to one hot encode some categorical variables and use Logistic regression

# %%
X = CombatsMM.loc[:,CombatsMM.columns != "Winner"]
y = CombatsMM.Winner

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=23,test_size = 0.2)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
X.First_pokemon =X.First_pokemon.map(pd.Series(Pokemon.Name,index=Pokemon.pid))

# %%
X.Second_pokemon =X.Second_pokemon.map(pd.Series(Pokemon.Name,index=Pokemon.pid))

# %%
oneh = OneHotEncoder()
XX = oneh.fit_transform(X[["First_pokemon","Second_pokemon"]])

# %%
XX_train,XX_test,yy_train,yy_test = train_test_split(XX,y,random_state=23,test_size = 0.2)

# %%
LogReg = LogisticRegression(fit_intercept=False)
LogReg.fit(XX_train,yy_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=False,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
LogReg.score(XX_train,yy_train),LogReg.score(XX_test,yy_test)
# Out:
# (0.8971749429724513, 0.8694605975536395)

# %%
#CV, 5-Fold
CVScores5 = cross_val_score(X=XX,y=y,cv=StratifiedKFold(n_splits=5,shuffle=True),
                           estimator=LogReg,n_jobs=2)

# %% [markdown]
# It seems to have good performances, and it simple, it just gives weights to pokemons, so it is the best model, but it is not scalable to new pokemons, if we want to predict the issue of a fight the two pokemons have to have an history of fights, we can not predict just depending on their characteristics.

# %%
#We add the coefficients as features and visualize the linear separation

# %%
corresp = pd.DataFrame(np.transpose([oneh.get_feature_names(),LogReg.coef_[0]]),columns=["name","coeff"])
corresp
# Out:
#                            name      coeff
# 0                  x0_Abomasnow  -0.121356
# 1                       x0_Abra   -2.53376
# 2                      x0_Absol  -0.816987
# 3                   x0_Accelgor     2.3731
# 4      x0_Aegislash Blade Forme    1.95015
# 5     x0_Aegislash Shield Forme   -1.18736
# 6                 x0_Aerodactyl   0.138437
# 7                     x0_Aggron    0.74349
# 8                      x0_Aipom    1.51139
# 9                   x0_Alakazam  -0.515881
# 10                 x0_Alomomola -0.0222052
# 11                   x0_Altaria  -0.502812
# 12                    x0_Amaura    1.30896
# 13                   x0_Ambipom    1.02878
# 14                 x0_Amoonguss   -1.88879
# 15                  x0_Ampharos   0.471357
# 16                   x0_Anorith   -2.83775
# 17                     x0_Arbok    1.11336
# 18                  x0_Arcanine    -1.0971
# 19                    x0_Arceus  -0.984248
# 20                    x0_Archen  -0.773865
# 21                  x0_Archeops    2.02733
# 22                   x0_Ariados   -1.98058
# 23                   x0_Armaldo  -0.713786
# 24                x0_Aromatisse   -1.52706
# 25                      x0_Aron    1.25546
# 26                  x0_Articuno    2.67754
# 27                    x0_Audino   -1.78694
# 28                   x0_Aurorus     1.6158
# 29                      x0_Axew   0.603151
# ...                         ...        ...
# 1536                  x1_Weedle    2.12731
# 1537              x1_Weepinbell    1.78363
# 1538                 x1_Weezing    -2.1448
# 1539              x1_Whimsicott  0.0869551
# 1540              x1_Whirlipede   0.604098
# 1541                x1_Whiscash  -0.562519
# 1542                 x1_Whismur    -1.3533
# 1543              x1_Wigglytuff    2.79753
# 1544                 x1_Wingull  -0.368347
# 1545               x1_Wobbuffet    2.05493
# 1546                  x1_Woobat    -0.9858
# 1547                  x1_Wooper     1.8144
# 1548    x1_Wormadam Plant Cloak    2.37985
# 1549    x1_Wormadam Sandy Cloak    1.89875
# 1550    x1_Wormadam Trash Cloak   -2.86939
# 1551                 x1_Wurmple   0.286599
# 1552                  x1_Wynaut   0.519509
# 1553                    x1_Xatu    1.35336
# 1554                  x1_Yamask  -0.108729
# 1555                   x1_Yanma    1.39977
# 1556                 x1_Yanmega   -1.12736
# 1557                x1_Zangoose    2.50868
# 1558                  x1_Zapdos     -3.046
# 1559               x1_Zebstrika   0.417142
# 1560                  x1_Zekrom  -0.449303
# 1561               x1_Zigzagoon  -0.715178
# 1562                 x1_Zoroark  -0.393337
# 1563                   x1_Zorua  -0.568735
# 1564                   x1_Zubat    1.69127
# 1565                x1_Zweilous   -1.88135
#
# [1566 rows x 2 columns]

# %%
X.First_pokemon = "x0_" + X.First_pokemon

# %%
X.Second_pokemon = "x1_" + X.Second_pokemon

# %%
a = X.First_pokemon.map(pd.Series(LogReg.coef_[0][:782],index=oneh.get_feature_names()[:782]))
b = X.Second_pokemon.map(pd.Series(LogReg.coef_[0][782:],index=oneh.get_feature_names()[782:]))

# %%
sns.scatterplot(a,b,data=CombatsMM,hue="Winner",s=5)

# %%
#look at if the coefficients are the same for same pokemon
Diff = list()
for N in Pokemon.Name:
    if len(corresp.loc[corresp.name.str.contains(N)]) == 2:
        print(corresp.loc[corresp.name.str.contains(N)])
        Diff.append(corresp.loc[corresp.name.str.contains(N),"coeff"].sum())
# Out:
#             name     coeff
# 297   x0_Ivysaur -0.965944
# 1080  x1_Ivysaur  0.674899
#                   name     coeff
# 441   x0_Mega Venusaur  0.751478
# 1224  x1_Mega Venusaur -0.232227
#               name      coeff
# 84   x0_Charmander  -0.360176
# 867  x1_Charmander  0.0707331
#               name      coeff
# 85   x0_Charmeleon  0.0505904
# 868  x1_Charmeleon  -0.142471
#                      name    coeff
# 408   x0_Mega Charizard X  2.63981
# 1191  x1_Mega Charizard X -2.32444
#                      name    coeff
# 409   x0_Mega Charizard Y   2.2595
# 1192  x1_Mega Charizard Y -2.07501
#              name    coeff
# 655   x0_Squirtle -1.69108
# 1438  x1_Squirtle  1.68857
#               name     coeff
# 749   x0_Wartortle -0.360818
# 1532  x1_Wartortle  0.622892
#                    name    coeff
# 405   x0_Mega Blastoise  -1.6457
# 1188  x1_Mega Blastoise  2.00782
#             name    coeff
# 79   x0_Caterpie -2.92133
# 862  x1_Caterpie  1.79231
#             name     coeff
# 451   x0_Metapod  0.113856
# 1234  x1_Metapod -0.677968
#               name    coeff
# 69   x0_Butterfree -1.56409
# 852  x1_Butterfree  1.31893
#            name    coeff
# 753   x0_Weedle -2.60957
# 1536  x1_Weedle  2.12731
#            name     coeff
# 308   x0_Kakuna  0.479622
# 1091  x1_Kakuna -0.406972
#                   name     coeff
# 404   x0_Mega Beedrill -0.585257
# 1187  x1_Mega Beedrill   0.79586
#            name     coeff
# 517   x0_Pidgey  0.172131
# 1300  x1_Pidgey -0.261003
#               name    coeff
# 516   x0_Pidgeotto  2.45412
# 1299  x1_Pidgeotto -2.04128
#                  name      coeff
# 429   x0_Mega Pidgeot -0.0255812
# 1212  x1_Mega Pidgeot  0.0738071
#             name    coeff
# 558   x0_Rattata  1.31116
# 1341  x1_Rattata -1.50784
#              name      coeff
# 557   x0_Raticate  -0.244734
# 1340  x1_Raticate  0.0299465
#             name    coeff
# 647   x0_Spearow  1.68188
# 1430  x1_Spearow  -2.2974
#           name     coeff
# 192  x0_Fearow -0.505642
# 975  x1_Fearow  0.792995
#          name     coeff
# 172  x0_Ekans  0.537025
# 955  x1_Ekans -0.675493
#          name     coeff
# 17   x0_Arbok   1.11336
# 800  x1_Arbok -0.978191
#             name    coeff
# 520   x0_Pikachu  2.30332
# 1303  x1_Pikachu -2.36344
#            name      coeff
# 552   x0_Raichu -0.0366114
# 1335  x1_Raichu  -0.127352
#               name    coeff
# 581   x0_Sandshrew -1.88919
# 1364  x1_Sandshrew  1.99579
#               name     coeff
# 582   x0_Sandslash -0.801976
# 1365  x1_Sandslash  0.355067
#                name      coeff
# 480   x0_Nidoranâ™€  0.0851429
# 1263  x1_Nidoranâ™€  -0.145543
#              name    coeff
# 481   x0_Nidorina -1.77413
# 1264  x1_Nidorina   1.0196
#               name     coeff
# 478   x0_Nidoqueen  -0.88017
# 1261  x1_Nidoqueen  0.489045
#                name     coeff
# 479   x0_Nidoranâ™‚  0.496141
# 1262  x1_Nidoranâ™‚ -0.690529
#              name    coeff
# 482   x0_Nidorino -2.43157
# 1265  x1_Nidorino  1.35455
#              name     coeff
# 477   x0_Nidoking -0.189061
# 1260  x1_Nidoking  0.772241
#             name     coeff
# 102  x0_Clefairy  -1.06502
# 885  x1_Clefairy  0.157738
#             name    coeff
# 101  x0_Clefable  1.79977
# 884  x1_Clefable -1.70688
#            name    coeff
# 745   x0_Vulpix -2.34172
# 1528  x1_Vulpix  2.94425
#               name     coeff
# 484   x0_Ninetales -0.640961
# 1267  x1_Ninetales  0.773909
#                name    coeff
# 299   x0_Jigglypuff  1.57849
# 1082  x1_Jigglypuff -1.27257
#                name    coeff
# 760   x0_Wigglytuff -2.81001
# 1543  x1_Wigglytuff  2.79753
#           name    coeff
# 781   x0_Zubat -1.41941
# 1564  x1_Zubat  1.69127
#            name     coeff
# 241   x0_Golbat  -1.34279
# 1024  x1_Golbat  0.484885
#            name    coeff
# 491   x0_Oddish -2.68113
# 1274  x1_Oddish  2.87868
#           name    coeff
# 239   x0_Gloom -2.12865
# 1022  x1_Gloom  1.35378
#               name    coeff
# 738   x0_Vileplume -1.41689
# 1521  x1_Vileplume  1.59462
#              name      coeff
# 505   x0_Parasect  0.0652178
# 1288  x1_Parasect  -0.117009
#             name    coeff
# 731   x0_Venonat  2.20501
# 1514  x1_Venonat -1.90691
#              name     coeff
# 730   x0_Venomoth  0.245115
# 1513  x1_Venomoth  -1.38572
#            name    coeff
# 143  x0_Diglett  1.76976
# 926  x1_Diglett -3.13982
#            name     coeff
# 160  x0_Dugtrio  -1.17881
# 943  x1_Dugtrio  0.526276
#            name     coeff
# 447   x0_Meowth  0.798602
# 1230  x1_Meowth -0.753567
#             name     coeff
# 509   x0_Persian -0.603172
# 1292  x1_Persian -0.278977
#             name    coeff
# 539   x0_Psyduck  1.24048
# 1322  x1_Psyduck -1.91266
#             name     coeff
# 243   x0_Golduck -0.421104
# 1026  x1_Golduck  0.174645
#            name    coeff
# 383   x0_Mankey  1.26945
# 1166  x1_Mankey -1.84995
#         name     coeff
# 475   x0_NaN  0.898455
# 1258  x1_NaN  -1.33981
#               name      coeff
# 260   x0_Growlithe    0.17156
# 1043  x1_Growlithe  0.0264061
#             name    coeff
# 18   x0_Arcanine  -1.0971
# 801  x1_Arcanine  1.01355
#             name     coeff
# 527   x0_Poliwag  0.206468
# 1310  x1_Poliwag  -1.49343
#               name    coeff
# 528   x0_Poliwhirl  1.60899
# 1311  x1_Poliwhirl -1.57334
#               name    coeff
# 529   x0_Poliwrath  2.12051
# 1312  x1_Poliwrath -1.33595
#         name    coeff
# 1    x0_Abra -2.53376
# 784  x1_Abra   2.3035
#             name    coeff
# 307   x0_Kadabra -1.48721
# 1090  x1_Kadabra  1.13914
#                   name    coeff
# 399   x0_Mega Alakazam  -1.6255
# 1182  x1_Mega Alakazam  1.52559
#            name     coeff
# 368   x0_Machop -0.987971
# 1151  x1_Machop  0.940111
#             name     coeff
# 367   x0_Machoke -0.128515
# 1150  x1_Machoke  0.162231
#             name    coeff
# 366   x0_Machamp  1.87972
# 1149  x1_Machamp -1.94439
#               name    coeff
# 47   x0_Bellsprout -2.35597
# 830  x1_Bellsprout  2.29034
#                name    coeff
# 754   x0_Weepinbell -1.45926
# 1537  x1_Weepinbell  1.78363
#                name     coeff
# 736   x0_Victreebel -0.975839
# 1519  x1_Victreebel  0.791269
#               name    coeff
# 687   x0_Tentacool   1.2004
# 1470  x1_Tentacool -1.40173
#                name    coeff
# 688   x0_Tentacruel  1.91883
# 1471  x1_Tentacruel -2.46108
#             name    coeff
# 228   x0_Geodude -1.29839
# 1011  x1_Geodude  1.91191
#              name    coeff
# 254   x0_Graveler -2.01209
# 1037  x1_Graveler  2.15031
#           name    coeff
# 244   x0_Golem -1.86982
# 1027  x1_Golem  2.36451
#            name    coeff
# 530   x0_Ponyta -1.91071
# 1313  x1_Ponyta  1.88184
#              name     coeff
# 556   x0_Rapidash -0.756719
# 1339  x1_Rapidash  0.347392
#              name     coeff
# 634   x0_Slowpoke  0.365625
# 1417  x1_Slowpoke -0.802833
#                  name    coeff
# 437   x0_Mega Slowbro -1.55062
# 1220  x1_Mega Slowbro  1.31233
#               name     coeff
# 374   x0_Magnemite -0.119052
# 1157  x1_Magnemite -0.389241
#              name    coeff
# 375   x0_Magneton -2.33703
# 1158  x1_Magneton  1.86281
#               name     coeff
# 191  x0_Farfetch'd -0.981136
# 974  x1_Farfetch'd   0.62767
#          name    coeff
# 146  x0_Doduo -1.94257
# 929  x1_Doduo   1.6415
#           name     coeff
# 145  x0_Dodrio   0.33441
# 928  x1_Dodrio -0.298296
#          name      coeff
# 596   x0_Seel  -0.342387
# 1379  x1_Seel  0.0113614
#            name    coeff
# 139  x0_Dewgong  0.85403
# 922  x1_Dewgong -1.18966
#            name    coeff
# 256   x0_Grimer  1.25315
# 1039  x1_Grimer -1.47841
#         name    coeff
# 470   x0_Muk  2.64717
# 1253  x1_Muk -1.64944
#              name     coeff
# 608   x0_Shellder -0.181264
# 1391  x1_Shellder  0.409118
#             name    coeff
# 104  x0_Cloyster -1.76167
# 887  x1_Cloyster  1.72205
#            name     coeff
# 224   x0_Gastly  0.171701
# 1007  x1_Gastly -0.112656
#             name    coeff
# 267   x0_Haunter -1.42566
# 1050  x1_Haunter  1.25184
#                 name     coeff
# 413   x0_Mega Gengar -0.255002
# 1196  x1_Mega Gengar  -1.15039
#          name    coeff
# 494   x0_Onix  1.83959
# 1277  x1_Onix -2.46898
#            name    coeff
# 157  x0_Drowzee -1.75239
# 940  x1_Drowzee  1.29129
#           name     coeff
# 292   x0_Hypno -0.558019
# 1075  x1_Hypno  0.387315
#            name    coeff
# 322   x0_Krabby -1.60885
# 1105  x1_Krabby  2.30539
#             name     coeff
# 315   x0_Kingler  -1.08629
# 1098  x1_Kingler  0.861705
#             name     coeff
# 743   x0_Voltorb  0.788968
# 1526  x1_Voltorb -0.677073
#              name     coeff
# 176  x0_Electrode  0.708123
# 959  x1_Electrode -0.309271
#              name    coeff
# 187  x0_Exeggcute -2.28921
# 970  x1_Exeggcute   2.0375
#              name    coeff
# 188  x0_Exeggutor -2.16262
# 971  x1_Exeggutor  2.27918
#           name     coeff
# 123  x0_Cubone  -0.66575
# 906  x1_Cubone  0.162519
#             name     coeff
# 389   x0_Marowak  -1.38812
# 1172  x1_Marowak  0.794531
#               name      coeff
# 280   x0_Hitmonlee  -0.662448
# 1063  x1_Hitmonlee  0.0470717
#                name    coeff
# 279   x0_Hitmonchan -1.40536
# 1062  x1_Hitmonchan  2.31181
#               name     coeff
# 346   x0_Lickitung -0.510967
# 1129  x1_Lickitung   0.82526
#             name    coeff
# 321   x0_Koffing  1.21968
# 1104  x1_Koffing  -1.6088
#             name    coeff
# 755   x0_Weezing  1.80909
# 1538  x1_Weezing  -2.1448
#             name     coeff
# 569   x0_Rhyhorn -0.676492
# 1352  x1_Rhyhorn  0.555203
#            name     coeff
# 568   x0_Rhydon   0.90815
# 1351  x1_Rhydon -0.862056
#            name     coeff
# 82   x0_Chansey -0.234045
# 865  x1_Chansey  0.108493
#             name     coeff
# 683   x0_Tangela  0.162005
# 1466  x1_Tangela  0.282411
#                     name    coeff
# 418   x0_Mega Kangaskhan  2.38607
# 1201  x1_Mega Kangaskhan   -1.842
#            name     coeff
# 287   x0_Horsea  0.455802
# 1070  x1_Horsea -0.122432
#            name    coeff
# 592   x0_Seadra  2.38324
# 1375  x1_Seadra -1.79339
#             name    coeff
# 242   x0_Goldeen  1.08892
# 1025  x1_Goldeen   -1.285
#             name    coeff
# 593   x0_Seaking  1.96033
# 1376  x1_Seaking  -2.2341
#            name    coeff
# 661   x0_Staryu  1.22423
# 1444  x1_Staryu -1.08753
#             name     coeff
# 660   x0_Starmie  0.835728
# 1443  x1_Starmie   -1.0383
#              name    coeff
# 468   x0_Mr. Mime  2.22687
# 1251  x1_Mr. Mime  -2.0934
#             name    coeff
# 591   x0_Scyther  1.94185
# 1374  x1_Scyther -2.83408
#          name    coeff
# 304   x0_Jynx -1.92132
# 1087  x1_Jynx  2.03352
#               name     coeff
# 173  x0_Electabuzz  0.997579
# 956  x1_Electabuzz -0.648164
#            name     coeff
# 372   x0_Magmar   1.01691
# 1155  x1_Magmar -0.989974
#                 name     coeff
# 430   x0_Mega Pinsir  -0.87436
# 1213  x1_Mega Pinsir  0.771468
#            name     coeff
# 685   x0_Tauros  -0.18938
# 1468  x1_Tauros -0.103334
#              name    coeff
# 371   x0_Magikarp  3.28343
# 1154  x1_Magikarp -2.48765
#                   name    coeff
# 415   x0_Mega Gyarados -2.15377
# 1198  x1_Mega Gyarados  1.71414
#            name    coeff
# 336   x0_Lapras -1.94534
# 1119  x1_Lapras  1.61762
#          name     coeff
# 144  x0_Ditto  -1.01798
# 927  x1_Ditto  0.690787
#          name     coeff
# 171  x0_Eevee -0.434375
# 954  x1_Eevee  0.658776
#              name     coeff
# 728   x0_Vaporeon  0.937768
# 1511  x1_Vaporeon -0.832001
#             name    coeff
# 301   x0_Jolteon  3.26912
# 1084  x1_Jolteon -3.12755
#            name    coeff
# 201  x0_Flareon  3.50445
# 984  x1_Flareon -3.11953
#             name     coeff
# 492   x0_Omanyte  0.956454
# 1275  x1_Omanyte  -1.16445
#             name    coeff
# 493   x0_Omastar  1.42019
# 1276  x1_Omastar -1.67639
#              name     coeff
# 306   x0_Kabutops  -1.21843
# 1089  x1_Kabutops  0.560396
#                     name    coeff
# 397   x0_Mega Aerodactyl  0.33488
# 1180  x1_Mega Aerodactyl -1.05087
#             name    coeff
# 641   x0_Snorlax  2.68373
# 1424  x1_Snorlax -2.90446
#             name    coeff
# 26   x0_Articuno  2.67754
# 809  x1_Articuno  -2.0965
#            name    coeff
# 775   x0_Zapdos  2.67034
# 1558  x1_Zapdos   -3.046
#             name    coeff
# 464   x0_Moltres  1.79597
# 1247  x1_Moltres -2.14148
#            name    coeff
# 153  x0_Dratini -1.06312
# 936  x1_Dratini  1.44958
#              name     coeff
# 150  x0_Dragonair -0.397772
# 933  x1_Dragonair  0.440966
#              name     coeff
# 151  x0_Dragonite  0.889119
# 934  x1_Dragonite  -0.79235
#                   name     coeff
# 427   x0_Mega Mewtwo X   0.42922
# 1210  x1_Mega Mewtwo X -0.264231
#                   name    coeff
# 428   x0_Mega Mewtwo Y  1.76884
# 1211  x1_Mega Mewtwo Y -2.13949
#              name     coeff
# 91   x0_Chikorita -0.734694
# 874  x1_Chikorita  0.468414
#            name     coeff
# 40   x0_Bayleef  0.959834
# 823  x1_Bayleef -0.066694
#              name    coeff
# 442   x0_Meganium -3.26728
# 1225  x1_Meganium  2.50001
#              name     coeff
# 124  x0_Cyndaquil  0.770055
# 907  x1_Cyndaquil  -1.25329
#             name     coeff
# 549   x0_Quilava -0.637871
# 1332  x1_Quilava   1.01541
#                name     coeff
# 715   x0_Typhlosion   -0.1716
# 1498  x1_Typhlosion -0.299729
#              name    coeff
# 704   x0_Totodile -1.32214
# 1487  x1_Totodile   1.3952
#             name     coeff
# 119  x0_Croconaw  0.495895
# 902  x1_Croconaw -0.919686
#               name    coeff
# 195  x0_Feraligatr -2.72678
# 978  x1_Feraligatr  2.05502
#             name    coeff
# 598   x0_Sentret  2.02167
# 1381  x1_Sentret -2.72442
#            name      coeff
# 217   x0_Furret -0.0529932
# 1000  x1_Furret -0.0490594
#              name       coeff
# 285   x0_Hoothoot  -0.0324645
# 1068  x1_Hoothoot  0.00233943
#             name     coeff
# 486   x0_Noctowl -0.698319
# 1269  x1_Noctowl  0.884651
#            name    coeff
# 344   x0_Ledyba -2.72319
# 1127  x1_Ledyba  2.74179
#            name    coeff
# 343   x0_Ledian -3.12092
# 1126  x1_Ledian  2.92397
#              name    coeff
# 650   x0_Spinarak  -2.9727
# 1433  x1_Spinarak  2.78247
#            name    coeff
# 22   x0_Ariados -1.98058
# 805  x1_Ariados  1.33508
#           name      coeff
# 118  x0_Crobat -0.0679576
# 901  x1_Crobat  -0.373528
#             name    coeff
# 94   x0_Chinchou  1.31345
# 877  x1_Chinchou -1.38105
#             name    coeff
# 335   x0_Lanturn -2.08505
# 1118  x1_Lanturn  1.91734
#           name    coeff
# 514   x0_Pichu -1.22403
# 1297  x1_Pichu  1.72498
#           name     coeff
# 103  x0_Cleffa  -1.07972
# 886  x1_Cleffa  0.744441
#               name    coeff
# 293   x0_Igglybuff -1.16656
# 1076  x1_Igglybuff  1.33334
#            name     coeff
# 697   x0_Togepi -0.961365
# 1480  x1_Togepi   1.44818
#             name    coeff
# 698   x0_Togetic -1.62494
# 1481  x1_Togetic  1.85319
#          name     coeff
# 476   x0_Natu  -1.22789
# 1259  x1_Natu  0.826943
#          name    coeff
# 770   x0_Xatu  -1.2259
# 1553  x1_Xatu  1.35336
#            name     coeff
# 387   x0_Mareep -0.266238
# 1170  x1_Mareep -0.732407
#            name     coeff
# 199  x0_Flaaffy  -1.18358
# 982  x1_Flaaffy  0.738788
#                   name    coeff
# 401   x0_Mega Ampharos  2.08195
# 1184  x1_Mega Ampharos -2.30104
#              name     coeff
# 46   x0_Bellossom  0.711162
# 829  x1_Bellossom  -1.34128
#            name    coeff
# 388   x0_Marill -2.62169
# 1171  x1_Marill  1.79933
#              name    coeff
# 31   x0_Azumarill -2.27003
# 814  x1_Azumarill  1.84447
#               name    coeff
# 666   x0_Sudowoodo  1.17326
# 1449  x1_Sudowoodo -1.39802
#              name    coeff
# 526   x0_Politoed -3.03571
# 1309  x1_Politoed  3.16716
#            name    coeff
# 286   x0_Hoppip -1.55788
# 1069  x1_Hoppip   1.5804
#              name    coeff
# 624   x0_Skiploom  1.87659
# 1407  x1_Skiploom  -2.1318
#              name     coeff
# 303   x0_Jumpluff -0.106223
# 1086  x1_Jumpluff -0.366708
#          name    coeff
# 8    x0_Aipom  1.51139
# 791  x1_Aipom -2.08078
#             name    coeff
# 669   x0_Sunkern -1.41593
# 1452  x1_Sunkern  1.28616
#              name     coeff
# 668   x0_Sunflora  0.487445
# 1451  x1_Sunflora  -1.45533
#           name    coeff
# 772   x0_Yanma -1.39543
# 1555  x1_Yanma  1.39977
#            name    coeff
# 764   x0_Wooper -2.43101
# 1547  x1_Wooper   1.8144
#              name     coeff
# 548   x0_Quagsire  0.537442
# 1331  x1_Quagsire -0.378522
#           name    coeff
# 184  x0_Espeon -2.41431
# 967  x1_Espeon  1.73202
#             name     coeff
# 720   x0_Umbreon   -1.4086
# 1503  x1_Umbreon  0.750925
#             name    coeff
# 473   x0_Murkrow  -1.4565
# 1256  x1_Murkrow  1.34388
#              name    coeff
# 633   x0_Slowking  1.17644
# 1416  x1_Slowking -1.01543
#                name    coeff
# 462   x0_Misdreavus -2.05248
# 1245  x1_Misdreavus  2.01119
#           name    coeff
# 722   x0_Unown -1.59572
# 1505  x1_Unown  0.75335
#               name    coeff
# 762   x0_Wobbuffet -1.87299
# 1545  x1_Wobbuffet  2.05493
#               name     coeff
# 231   x0_Girafarig -0.632238
# 1014  x1_Girafarig   1.07744
#            name    coeff
# 522   x0_Pineco  1.15492
# 1305  x1_Pineco -1.28316
#               name     coeff
# 209  x0_Forretress  0.285965
# 992  x1_Forretress -0.145554
#              name     coeff
# 161  x0_Dunsparce  0.413932
# 944  x1_Dunsparce -0.565623
#            name    coeff
# 237   x0_Gligar -3.60232
# 1020  x1_Gligar  3.43194
#                  name     coeff
# 438   x0_Mega Steelix  0.602959
# 1221  x1_Mega Steelix  -0.62958
#              name    coeff
# 644   x0_Snubbull  2.43114
# 1427  x1_Snubbull -2.79317
#              name     coeff
# 253   x0_Granbull  -1.80611
# 1036  x1_Granbull  0.955511
#              name    coeff
# 551   x0_Qwilfish -2.95807
# 1334  x1_Qwilfish  3.19931
#                 name    coeff
# 435   x0_Mega Scizor -1.28514
# 1218  x1_Mega Scizor  1.08223
#             name    coeff
# 615   x0_Shuckle -1.05058
# 1398  x1_Shuckle  0.92025
#                    name     coeff
# 416   x0_Mega Heracross -0.284982
# 1199  x1_Mega Heracross  0.177639
#             name     coeff
# 639   x0_Sneasel  -1.31734
# 1422  x1_Sneasel  0.925306
#               name     coeff
# 686   x0_Teddiursa  0.616187
# 1469  x1_Teddiursa -0.203941
#              name     coeff
# 723   x0_Ursaring  0.381542
# 1506  x1_Ursaring -0.285973
#            name     coeff
# 635   x0_Slugma  0.365455
# 1418  x1_Slugma  0.154666
#              name     coeff
# 370   x0_Magcargo -0.328682
# 1153  x1_Magcargo -0.248873
#            name    coeff
# 677   x0_Swinub  1.69055
# 1460  x1_Swinub -1.67085
#               name    coeff
# 521   x0_Piloswine  2.93241
# 1304  x1_Piloswine -2.91232
#            name     coeff
# 111  x0_Corsola  0.808955
# 894  x1_Corsola  -1.21681
#              name    coeff
# 565   x0_Remoraid -1.51264
# 1348  x1_Remoraid  1.40017
#               name     coeff
# 490   x0_Octillery   -1.1321
# 1273  x1_Octillery  0.601584
#             name      coeff
# 133  x0_Delibird  -0.430477
# 916  x1_Delibird -0.0470098
#             name     coeff
# 384   x0_Mantine  0.833048
# 1167  x1_Mantine -0.842074
#              name     coeff
# 622   x0_Skarmory -0.674722
# 1405  x1_Skarmory  0.738919
#              name    coeff
# 289   x0_Houndour -2.42436
# 1072  x1_Houndour  2.00023
#                   name     coeff
# 417   x0_Mega Houndoom   -1.1955
# 1200  x1_Mega Houndoom  0.794763
#             name    coeff
# 314   x0_Kingdra  1.30698
# 1097  x1_Kingdra -1.89262
#            name     coeff
# 511   x0_Phanpy  0.871846
# 1294  x1_Phanpy -0.529877
#            name    coeff
# 147  x0_Donphan  1.58432
# 930  x1_Donphan -1.78442
#              name    coeff
# 534   x0_Porygon2 -1.66916
# 1317  x1_Porygon2   1.1632
#              name    coeff
# 656   x0_Stantler  3.00891
# 1439  x1_Stantler -2.82362
#              name    coeff
# 637   x0_Smeargle  2.17717
# 1420  x1_Smeargle -1.41077
#             name     coeff
# 718   x0_Tyrogue  0.396737
# 1501  x1_Tyrogue  -1.02495
#               name    coeff
# 281   x0_Hitmontop -1.75311
# 1064  x1_Hitmontop  1.79026
#              name    coeff
# 638   x0_Smoochum -1.25915
# 1421  x1_Smoochum  1.23558
#           name      coeff
# 177  x0_Elekid  0.0300199
# 960  x1_Elekid   0.108867
#           name     coeff
# 369   x0_Magby  0.230124
# 1152  x1_Magby  -0.60516
#             name    coeff
# 458   x0_Miltank  2.22956
# 1241  x1_Miltank  -2.6594
#            name     coeff
# 54   x0_Blissey   1.30413
# 837  x1_Blissey -0.815351
#            name    coeff
# 553   x0_Raikou  1.59897
# 1336  x1_Raikou -1.78714
#          name     coeff
# 182  x0_Entei -0.255534
# 965  x1_Entei  0.235398
#             name    coeff
# 667   x0_Suicune  0.99484
# 1450  x1_Suicune  -1.2374
#              name    coeff
# 338   x0_Larvitar  2.56429
# 1121  x1_Larvitar -2.74994
#             name    coeff
# 544   x0_Pupitar  2.66415
# 1327  x1_Pupitar -2.72428
#                    name     coeff
# 440   x0_Mega Tyranitar -0.520318
# 1223  x1_Mega Tyranitar  0.350742
#           name     coeff
# 360   x0_Lugia   0.61502
# 1143  x1_Lugia -0.518226
#           name    coeff
# 282   x0_Ho-oh  1.95903
# 1065  x1_Ho-oh -1.93485
#           name    coeff
# 80   x0_Celebi  -2.0284
# 863  x1_Celebi  2.02926
#             name    coeff
# 708   x0_Treecko -1.01657
# 1491  x1_Treecko   1.1324
#             name     coeff
# 259   x0_Grovyle -0.405639
# 1042  x1_Grovyle -0.209117
#                   name    coeff
# 434   x0_Mega Sceptile -1.27831
# 1217  x1_Mega Sceptile  1.30798
#             name     coeff
# 699   x0_Torchic  0.716686
# 1482  x1_Torchic -0.641901
#              name     coeff
# 108  x0_Combusken  -1.59336
# 891  x1_Combusken  0.429612
#                   name    coeff
# 406   x0_Mega Blaziken -2.59433
# 1189  x1_Mega Blaziken  2.74998
#            name    coeff
# 469   x0_Mudkip   -3.558
# 1252  x1_Mudkip  3.09725
#               name     coeff
# 390   x0_Marshtomp -0.258146
# 1173  x1_Marshtomp -0.375786
#                   name     coeff
# 439   x0_Mega Swampert -0.318088
# 1222  x1_Mega Swampert  0.698111
#               name    coeff
# 531   x0_Poochyena -2.78315
# 1314  x1_Poochyena   2.6852
#               name    coeff
# 456   x0_Mightyena -1.59439
# 1239  x1_Mightyena  1.26064
#               name     coeff
# 778   x0_Zigzagoon  -0.16918
# 1561  x1_Zigzagoon -0.715178
#             name    coeff
# 351   x0_Linoone  -2.6252
# 1134  x1_Linoone  2.20572
#             name     coeff
# 768   x0_Wurmple -0.944183
# 1551  x1_Wurmple  0.286599
#             name     coeff
# 618   x0_Silcoon  0.638548
# 1401  x1_Silcoon  -1.14383
#              name     coeff
# 42   x0_Beautifly  0.647922
# 825  x1_Beautifly  -1.55334
#            name    coeff
# 77   x0_Cascoon   2.3854
# 860  x1_Cascoon -2.71225
#           name      coeff
# 167  x0_Dustox  -0.149693
# 950  x1_Dustox  0.0627578
#           name     coeff
# 356   x0_Lotad -0.490969
# 1139  x1_Lotad -0.184619
#            name    coeff
# 354   x0_Lombre -1.85058
# 1137  x1_Lombre  2.27694
#              name    coeff
# 359   x0_Ludicolo -1.17609
# 1142  x1_Ludicolo  1.14845
#            name     coeff
# 595   x0_Seedot  0.780017
# 1378  x1_Seedot -0.929294
#             name    coeff
# 489   x0_Nuzleaf  1.42194
# 1272  x1_Nuzleaf -1.93306
#             name     coeff
# 612   x0_Shiftry -0.736566
# 1395  x1_Shiftry  0.674002
#             name     coeff
# 681   x0_Taillow -0.421486
# 1464  x1_Taillow  0.338971
#             name    coeff
# 676   x0_Swellow -2.00565
# 1459  x1_Swellow  1.72023
#             name     coeff
# 761   x0_Wingull  0.403321
# 1544  x1_Wingull -0.368347
#              name    coeff
# 508   x0_Pelipper -2.58668
# 1291  x1_Pelipper  2.10158
#           name     coeff
# 554   x0_Ralts  0.352883
# 1337  x1_Ralts  -1.01468
#            name    coeff
# 316   x0_Kirlia  2.06357
# 1099  x1_Kirlia -2.82835
#                    name    coeff
# 412   x0_Mega Gardevoir  2.37294
# 1195  x1_Mega Gardevoir -3.00607
#             name     coeff
# 670   x0_Surskit  -2.60867
# 1453  x1_Surskit -0.266047
#                name    coeff
# 391   x0_Masquerain -2.79865
# 1174  x1_Masquerain   2.3537
#               name     coeff
# 614   x0_Shroomish  -1.64939
# 1397  x1_Shroomish  0.859816
#            name     coeff
# 61   x0_Breloom -0.245117
# 844  x1_Breloom -0.267972
#             name    coeff
# 630   x0_Slakoth -1.77021
# 1413  x1_Slakoth  2.27865
#              name    coeff
# 737   x0_Vigoroth -3.11853
# 1520  x1_Vigoroth  2.61753
#             name    coeff
# 629   x0_Slaking -2.83659
# 1412  x1_Slaking  2.32048
#             name    coeff
# 483   x0_Nincada  -1.1692
# 1266  x1_Nincada  1.21445
#             name     coeff
# 485   x0_Ninjask -0.493581
# 1268  x1_Ninjask -0.209737
#              name     coeff
# 606   x0_Shedinja   -1.8617
# 1389  x1_Shedinja -0.829771
#             name    coeff
# 759   x0_Whismur -1.86629
# 1542  x1_Whismur  -1.3533
#             name     coeff
# 357   x0_Loudred -0.944403
# 1140  x1_Loudred  0.665939
#            name     coeff
# 189  x0_Exploud -0.742949
# 972  x1_Exploud  0.432633
#              name    coeff
# 377   x0_Makuhita -1.78447
# 1160  x1_Makuhita  1.56369
#              name    coeff
# 266   x0_Hariyama -1.19847
# 1049  x1_Hariyama  1.36707
#            name     coeff
# 32   x0_Azurill -0.734493
# 815  x1_Azurill  0.585643
#              name     coeff
# 487   x0_Nosepass  -1.26681
# 1270  x1_Nosepass  0.643919
#            name     coeff
# 625   x0_Skitty  -1.09853
# 1408  x1_Skitty  0.795595
#             name     coeff
# 132  x0_Delcatty  0.643645
# 915  x1_Delcatty   -1.1665
#                  name      coeff
# 432   x0_Mega Sableye -0.0780926
# 1215  x1_Mega Sableye   -0.23356
#                 name    coeff
# 424   x0_Mega Mawile  2.75115
# 1207  x1_Mega Mawile -2.18219
#         name    coeff
# 25   x0_Aron  1.25546
# 808  x1_Aron -1.36093
#            name     coeff
# 331   x0_Lairon  0.633145
# 1114  x1_Lairon -0.715294
#                 name     coeff
# 398   x0_Mega Aggron  0.477736
# 1181  x1_Mega Aggron  -1.03719
#              name     coeff
# 394   x0_Meditite  -0.29698
# 1177  x1_Meditite  0.131929
#                   name     coeff
# 425   x0_Mega Medicham  -1.07726
# 1208  x1_Mega Medicham  0.404405
#              name      coeff
# 175  x0_Electrike  0.0871993
# 958  x1_Electrike   0.033926
#                    name    coeff
# 423   x0_Mega Manectric  2.44169
# 1206  x1_Mega Manectric -2.93853
#            name     coeff
# 525   x0_Plusle -0.670299
# 1308  x1_Plusle  0.300986
#           name     coeff
# 461   x0_Minun -0.664955
# 1244  x1_Minun  0.207494
#             name    coeff
# 741   x0_Volbeat -1.75514
# 1524  x1_Volbeat  1.44511
#              name    coeff
# 294   x0_Illumise  -1.1172
# 1077  x1_Illumise  1.93051
#             name    coeff
# 573   x0_Roselia -1.26564
# 1356  x1_Roselia  1.16943
#            name     coeff
# 262   x0_Gulpin -0.853656
# 1045  x1_Gulpin   1.71075
#            name     coeff
# 673   x0_Swalot -0.666007
# 1456  x1_Swalot  0.998983
#             name     coeff
# 76   x0_Carvanha  0.251791
# 859  x1_Carvanha -0.202334
#                   name    coeff
# 436   x0_Mega Sharpedo -1.05002
# 1219  x1_Mega Sharpedo  1.29447
#             name      coeff
# 746   x0_Wailmer  0.0224823
# 1529  x1_Wailmer  -0.325846
#             name    coeff
# 747   x0_Wailord  2.02067
# 1530  x1_Wailord -2.36885
#           name    coeff
# 488   x0_Numel -2.29029
# 1271  x1_Numel  1.67745
#                   name     coeff
# 407   x0_Mega Camerupt  -1.27757
# 1190  x1_Mega Camerupt  0.856394
#             name     coeff
# 700   x0_Torkoal  0.934774
# 1483  x1_Torkoal -0.676324
#            name     coeff
# 653   x0_Spoink   1.00545
# 1436  x1_Spoink -0.387769
#             name     coeff
# 261   x0_Grumpig  0.754696
# 1044  x1_Grumpig  -1.58934
#            name     coeff
# 651   x0_Spinda -0.495415
# 1434  x1_Spinda  0.279797
#              name      coeff
# 707   x0_Trapinch  0.0369921
# 1490  x1_Trapinch  -0.197893
#             name      coeff
# 734   x0_Vibrava -0.0888266
# 1517  x1_Vibrava  0.0974682
#           name     coeff
# 207  x0_Flygon -0.504925
# 990  x1_Flygon -0.267778
#           name     coeff
# 70   x0_Cacnea -0.791072
# 853  x1_Cacnea  0.908754
#             name    coeff
# 71   x0_Cacturne -2.65393
# 854  x1_Cacturne  2.10377
#            name     coeff
# 671   x0_Swablu -0.943894
# 1454  x1_Swablu  0.927256
#                  name     coeff
# 400   x0_Mega Altaria  0.276254
# 1183  x1_Mega Altaria -0.712007
#              name    coeff
# 774   x0_Zangoose -2.41411
# 1557  x1_Zangoose  2.50868
#             name    coeff
# 601   x0_Seviper -1.63466
# 1384  x1_Seviper  1.60944
#              name      coeff
# 362   x0_Lunatone   0.382191
# 1145  x1_Lunatone  0.0373411
#             name     coeff
# 646   x0_Solrock  -1.37687
# 1429  x1_Solrock  0.346864
#             name     coeff
# 37   x0_Barboach  -1.82032
# 820  x1_Barboach  0.801563
#              name     coeff
# 758   x0_Whiscash  0.436336
# 1541  x1_Whiscash -0.562519
#             name     coeff
# 110  x0_Corphish -0.228472
# 893  x1_Corphish -0.296969
#              name     coeff
# 115  x0_Crawdaunt  -1.90507
# 898  x1_Crawdaunt  0.865067
#           name     coeff
# 34   x0_Baltoy  -1.81318
# 817  x1_Baltoy  0.709789
#            name     coeff
# 100  x0_Claydol -0.673278
# 883  x1_Claydol -0.466249
#            name     coeff
# 348   x0_Lileep  0.659738
# 1131  x1_Lileep -0.806331
#            name    coeff
# 113  x0_Cradily -2.86371
# 896  x1_Cradily  1.64542
#            name    coeff
# 16   x0_Anorith -2.83775
# 799  x1_Anorith  1.41724
#            name     coeff
# 23   x0_Armaldo -0.713786
# 806  x1_Armaldo  0.667784
#           name     coeff
# 193  x0_Feebas -0.296256
# 976  x1_Feebas  0.120572
#             name    coeff
# 457   x0_Milotic  0.91056
# 1240  x1_Milotic -0.81531
#             name    coeff
# 78   x0_Castform  2.77366
# 861  x1_Castform -2.97806
#             name    coeff
# 311   x0_Kecleon -2.55469
# 1094  x1_Kecleon  3.09892
#             name    coeff
# 616   x0_Shuppet -1.15414
# 1399  x1_Shuppet  1.60395
#                  name    coeff
# 403   x0_Mega Banette  1.64789
# 1186  x1_Mega Banette -2.12494
#            name    coeff
# 166  x0_Duskull -2.65499
# 949  x1_Duskull  3.00644
#             name    coeff
# 164  x0_Dusclops -1.58316
# 947  x1_Dusclops  1.16851
#             name     coeff
# 710   x0_Tropius -0.282444
# 1493  x1_Tropius  0.201417
#             name    coeff
# 93   x0_Chimecho  -1.6937
# 876  x1_Chimecho  2.23842
#                name     coeff
# 396   x0_Mega Absol -0.946219
# 1179  x1_Mega Absol  0.922096
#            name     coeff
# 769   x0_Wynaut -0.614722
# 1552  x1_Wynaut  0.519509
#             name     coeff
# 642   x0_Snorunt  0.815144
# 1425  x1_Snorunt -0.480755
#                 name    coeff
# 414   x0_Mega Glalie  -1.2333
# 1197  x1_Mega Glalie  0.73885
#            name    coeff
# 649   x0_Spheal  1.88852
# 1432  x1_Spheal -2.02522
#            name    coeff
# 594   x0_Sealeo  2.51362
# 1377  x1_Sealeo -2.83028
#             name    coeff
# 748   x0_Walrein -2.36365
# 1531  x1_Walrein   1.9458
#             name     coeff
# 97   x0_Clamperl  -1.10204
# 880  x1_Clamperl  0.838079
#             name     coeff
# 290   x0_Huntail  0.232613
# 1073  x1_Huntail -0.164282
#              name    coeff
# 249   x0_Gorebyss   2.4232
# 1032  x1_Gorebyss -2.55985
#               name     coeff
# 564   x0_Relicanth  -1.13596
# 1347  x1_Relicanth  0.884999
#             name    coeff
# 363   x0_Luvdisc -1.42504
# 1146  x1_Luvdisc  1.48953
#          name    coeff
# 33   x0_Bagon -1.03701
# 816  x1_Bagon  1.09164
#             name    coeff
# 607   x0_Shelgon  2.38414
# 1390  x1_Shelgon -1.55219
#                    name    coeff
# 433   x0_Mega Salamence  2.25553
# 1216  x1_Mega Salamence -2.49005
#           name    coeff
# 45   x0_Beldum  1.17077
# 828  x1_Beldum  -1.1532
#            name    coeff
# 450   x0_Metang  1.36699
# 1233  x1_Metang -1.43871
#                    name    coeff
# 426   x0_Mega Metagross  1.62521
# 1209  x1_Mega Metagross -1.34596
#              name    coeff
# 562   x0_Regirock  1.76563
# 1345  x1_Regirock -1.85795
#            name    coeff
# 560   x0_Regice  2.72158
# 1343  x1_Regice -3.09772
#               name    coeff
# 563   x0_Registeel  2.01984
# 1346  x1_Registeel -2.40113
#                 name    coeff
# 419   x0_Mega Latias  2.79215
# 1202  x1_Mega Latias -2.18113
#                 name    coeff
# 420   x0_Mega Latios  2.69182
# 1203  x1_Mega Latios -2.88033
#                   name    coeff
# 536   x0_Primal Kyogre -1.42501
# 1319  x1_Primal Kyogre  1.12057
#                    name     coeff
# 535   x0_Primal Groudon -0.123374
# 1318  x1_Primal Groudon  0.171017
#                   name    coeff
# 431   x0_Mega Rayquaza  2.66475
# 1214  x1_Mega Rayquaza  -2.5198
#             name    coeff
# 300   x0_Jirachi -2.29795
# 1083  x1_Jirachi  1.74758
#                        name    coeff
# 137  x0_Deoxys Normal Forme -1.20802
# 920  x1_Deoxys Normal Forme  1.24263
#                        name     coeff
# 135  x0_Deoxys Attack Forme -0.550198
# 918  x1_Deoxys Attack Forme  0.108794
#                         name     coeff
# 136  x0_Deoxys Defense Forme -0.279265
# 919  x1_Deoxys Defense Forme  0.296325
#                       name     coeff
# 138  x0_Deoxys Speed Forme  0.466846
# 921  x1_Deoxys Speed Forme -0.660109
#             name    coeff
# 712   x0_Turtwig  1.79565
# 1495  x1_Turtwig -2.11333
#            name    coeff
# 257   x0_Grotle -2.06504
# 1040  x1_Grotle  2.20138
#              name      coeff
# 703   x0_Torterra  0.0695644
# 1486  x1_Torterra  -0.582928
#             name    coeff
# 92   x0_Chimchar -2.48114
# 875  x1_Chimchar  2.76199
#              name      coeff
# 465   x0_Monferno -0.0916931
# 1248  x1_Monferno  0.0262159
#               name    coeff
# 295   x0_Infernape -1.73006
# 1078  x1_Infernape  1.37692
#            name     coeff
# 524   x0_Piplup -0.686609
# 1307  x1_Piplup  0.521364
#              name     coeff
# 537   x0_Prinplup  0.639414
# 1320  x1_Prinplup -0.131404
#             name    coeff
# 181  x0_Empoleon -1.18937
# 964  x1_Empoleon   1.2836
#            name     coeff
# 659   x0_Starly  0.958306
# 1442  x1_Starly  -1.13376
#              name     coeff
# 658   x0_Staravia -0.626276
# 1441  x1_Staravia   1.04937
#               name     coeff
# 657   x0_Staraptor  -0.62414
# 1440  x1_Staraptor  0.174006
#           name    coeff
# 49   x0_Bidoof -2.31881
# 832  x1_Bidoof  2.42065
#            name    coeff
# 48   x0_Bibarel -2.67102
# 831  x1_Bibarel  1.29721
#               name    coeff
# 323   x0_Kricketot -2.27097
# 1106  x1_Kricketot  2.15996
#                name    coeff
# 324   x0_Kricketune -2.42816
# 1107  x1_Kricketune   1.8712
#           name    coeff
# 613   x0_Shinx -2.03805
# 1396  x1_Shinx  1.69077
#           name    coeff
# 364   x0_Luxio -1.19548
# 1147  x1_Luxio   1.3036
#            name      coeff
# 365   x0_Luxray  0.0408733
# 1148  x1_Luxray   0.141277
#          name     coeff
# 64   x0_Budew -0.689573
# 847  x1_Budew -0.130462
#              name     coeff
# 574   x0_Roserade  -1.51727
# 1357  x1_Roserade  0.958273
#             name     coeff
# 114  x0_Cranidos  0.734251
# 897  x1_Cranidos  -1.33969
#               name     coeff
# 555   x0_Rampardos  0.968485
# 1338  x1_Rampardos   -1.0099
#              name    coeff
# 611   x0_Shieldon  2.52861
# 1394  x1_Shieldon -2.85496
#              name    coeff
# 39   x0_Bastiodon -1.90489
# 822  x1_Bastiodon  1.89928
#          name     coeff
# 68   x0_Burmy  0.859261
# 851  x1_Burmy -0.792181
#                          name    coeff
# 765   x0_Wormadam Plant Cloak -2.19712
# 1548  x1_Wormadam Plant Cloak  2.37985
#                          name    coeff
# 766   x0_Wormadam Sandy Cloak -1.65308
# 1549  x1_Wormadam Sandy Cloak  1.89875
#                          name    coeff
# 767   x0_Wormadam Trash Cloak  2.37871
# 1550  x1_Wormadam Trash Cloak -2.86939
#            name      coeff
# 466   x0_Mothim  0.0871564
# 1249  x1_Mothim  -0.877137
#           name     coeff
# 107  x0_Combee  0.291145
# 890  x1_Combee -0.668602
#               name     coeff
# 733   x0_Vespiquen   0.86489
# 1516  x1_Vespiquen -0.906425
#               name    coeff
# 496   x0_Pachirisu  2.43459
# 1279  x1_Pachirisu  -1.9616
#           name    coeff
# 65   x0_Buizel  2.70613
# 848  x1_Buizel -2.86887
#             name    coeff
# 204  x0_Floatzel  1.44143
# 987  x1_Floatzel -2.85509
#            name     coeff
# 88   x0_Cherubi  0.467759
# 871  x1_Cherubi  -1.25329
#            name    coeff
# 87   x0_Cherrim   2.6743
# 870  x1_Cherrim -2.45573
#             name    coeff
# 609   x0_Shellos -1.91007
# 1392  x1_Shellos  2.10186
#               name     coeff
# 225   x0_Gastrodon  0.120788
# 1008  x1_Gastrodon -0.117923
#            name    coeff
# 13   x0_Ambipom  1.02878
# 796  x1_Ambipom -1.18286
#             name    coeff
# 155  x0_Drifloon -2.14993
# 938  x1_Drifloon  2.47517
#             name    coeff
# 154  x0_Drifblim -1.86947
# 937  x1_Drifblim  1.05919
#            name    coeff
# 66   x0_Buneary -1.63952
# 849  x1_Buneary    1.079
#                  name    coeff
# 421   x0_Mega Lopunny -3.04067
# 1204  x1_Mega Lopunny  2.29869
#               name    coeff
# 463   x0_Mismagius  1.36151
# 1246  x1_Mismagius -1.78696
#               name    coeff
# 283   x0_Honchkrow -1.14882
# 1066  x1_Honchkrow  1.34124
#             name    coeff
# 236   x0_Glameow -1.40568
# 1019  x1_Glameow  1.43775
#             name     coeff
# 546   x0_Purugly  0.543957
# 1329  x1_Purugly -0.275539
#              name    coeff
# 95   x0_Chingling  1.28323
# 878  x1_Chingling -1.54763
#            name     coeff
# 665   x0_Stunky   1.11136
# 1448  x1_Stunky -0.907308
#              name     coeff
# 628   x0_Skuntank  0.912063
# 1411  x1_Skuntank -0.224954
#            name     coeff
# 63   x0_Bronzor -0.894484
# 846  x1_Bronzor  0.135809
#             name    coeff
# 62   x0_Bronzong  1.44402
# 845  x1_Bronzong -1.27628
#           name    coeff
# 57   x0_Bonsly  1.99782
# 840  x1_Bonsly -2.71102
#              name    coeff
# 459   x0_Mime Jr. -1.31614
# 1242  x1_Mime Jr.  1.53414
#             name     coeff
# 265   x0_Happiny  -1.11162
# 1048  x1_Happiny  0.637397
#           name      coeff
# 86   x0_Chatot -0.0227276
# 869  x1_Chatot   0.143437
#               name    coeff
# 652   x0_Spiritomb  1.54124
# 1435  x1_Spiritomb -1.29732
#           name     coeff
# 229   x0_Gible -0.841434
# 1012  x1_Gible    1.1992
#            name     coeff
# 218   x0_Gabite  0.592025
# 1001  x1_Gabite  -1.06103
#                   name      coeff
# 411   x0_Mega Garchomp -0.0135612
# 1194  x1_Mega Garchomp  -0.206768
#              name     coeff
# 471   x0_Munchlax  0.824034
# 1254  x1_Munchlax -0.987503
#           name    coeff
# 571   x0_Riolu -1.15679
# 1354  x1_Riolu  2.28176
#                  name     coeff
# 422   x0_Mega Lucario -0.326528
# 1205  x1_Mega Lucario -0.109497
#                name     coeff
# 277   x0_Hippopotas -0.693212
# 1060  x1_Hippopotas   1.00319
#               name    coeff
# 278   x0_Hippowdon  3.24221
# 1061  x1_Hippowdon -3.23498
#             name     coeff
# 626   x0_Skorupi -0.354058
# 1409  x1_Skorupi -0.150112
#            name    coeff
# 152  x0_Drapion -1.27136
# 935  x1_Drapion  1.36596
#             name     coeff
# 117  x0_Croagunk -0.348958
# 900  x1_Croagunk  0.419249
#               name     coeff
# 705   x0_Toxicroak -0.641912
# 1488  x1_Toxicroak  0.761476
#              name    coeff
# 74   x0_Carnivine  1.38809
# 857  x1_Carnivine -1.35643
#            name    coeff
# 198  x0_Finneon  1.27802
# 981  x1_Finneon  -0.6549
#              name     coeff
# 361   x0_Lumineon   0.28975
# 1144  x1_Lumineon -0.629266
#             name    coeff
# 385   x0_Mantyke  1.72397
# 1168  x1_Mantyke -1.05175
#            name    coeff
# 643   x0_Snover  1.81994
# 1426  x1_Snover -1.75157
#                    name    coeff
# 395   x0_Mega Abomasnow  2.17492
# 1178  x1_Mega Abomasnow -1.44378
#             name     coeff
# 752   x0_Weavile  0.654036
# 1535  x1_Weavile  -0.14413
#               name     coeff
# 376   x0_Magnezone  0.628862
# 1159  x1_Magnezone  -1.56771
#                name     coeff
# 345   x0_Lickilicky  0.839337
# 1128  x1_Lickilicky -0.738851
#               name    coeff
# 570   x0_Rhyperior  2.32172
# 1353  x1_Rhyperior -2.23785
#               name    coeff
# 684   x0_Tangrowth -1.70728
# 1467  x1_Tangrowth  1.24622
#               name    coeff
# 174  x0_Electivire -1.54356
# 957  x1_Electivire  1.07694
#               name     coeff
# 373   x0_Magmortar -0.776353
# 1156  x1_Magmortar  -3.12082
#              name    coeff
# 696   x0_Togekiss -0.73482
# 1479  x1_Togekiss -1.90075
#             name     coeff
# 773   x0_Yanmega  0.896978
# 1556  x1_Yanmega  -1.12736
#             name    coeff
# 341   x0_Leafeon  1.36725
# 1124  x1_Leafeon -1.17199
#             name     coeff
# 234   x0_Glaceon  0.945321
# 1017  x1_Glaceon  -1.08803
#             name     coeff
# 238   x0_Gliscor  0.864579
# 1021  x1_Gliscor  -1.18044
#               name    coeff
# 379   x0_Mamoswine  1.39637
# 1162  x1_Mamoswine -1.19522
#               name    coeff
# 533   x0_Porygon-Z  1.42779
# 1316  x1_Porygon-Z -1.49254
#                  name    coeff
# 410   x0_Mega Gallade  2.28192
# 1193  x1_Mega Gallade -3.27686
#               name    coeff
# 538   x0_Probopass  1.39577
# 1321  x1_Probopass -1.78124
#             name    coeff
# 165  x0_Dusknoir  1.63844
# 948  x1_Dusknoir  -1.6459
#             name     coeff
# 214  x0_Froslass  0.948548
# 997  x1_Froslass -0.502696
#                name    coeff
# 270   x0_Heat Rotom  0.94695
# 1053  x1_Heat Rotom -1.63249
#                name     coeff
# 750   x0_Wash Rotom  0.372145
# 1533  x1_Wash Rotom  -1.66995
#                name     coeff
# 215  x0_Frost Rotom  0.826635
# 998  x1_Frost Rotom -0.752991
#              name     coeff
# 190  x0_Fan Rotom  0.236324
# 973  x1_Fan Rotom -0.737082
#               name    coeff
# 467   x0_Mow Rotom  1.98684
# 1250  x1_Mow Rotom -2.10074
#          name    coeff
# 724   x0_Uxie  2.62404
# 1507  x1_Uxie -2.89222
#             name    coeff
# 448   x0_Mesprit  1.85738
# 1231  x1_Mesprit -2.43566
#          name    coeff
# 30   x0_Azelf  3.08882
# 813  x1_Azelf -2.81299
#           name    coeff
# 141  x0_Dialga  3.12748
# 924  x1_Dialga -3.05275
#            name    coeff
# 497   x0_Palkia  2.11322
# 1280  x1_Palkia  -2.1628
#             name     coeff
# 272   x0_Heatran -0.282815
# 1055  x1_Heatran  0.191482
#               name    coeff
# 561   x0_Regigigas  2.16819
# 1344  x1_Regigigas -3.17945
#                            name    coeff
# 232   x0_Giratina Altered Forme -1.07658
# 1015  x1_Giratina Altered Forme  1.38371
#                           name     coeff
# 233   x0_Giratina Origin Forme -0.569884
# 1016  x1_Giratina Origin Forme  0.789287
#              name     coeff
# 116  x0_Cresselia  -0.10613
# 899  x1_Cresselia -0.509234
#            name    coeff
# 513   x0_Phione -1.14428
# 1296  x1_Phione  1.31005
#             name     coeff
# 380   x0_Manaphy -0.855773
# 1163  x1_Manaphy  0.294512
#            name     coeff
# 125  x0_Darkrai  0.361946
# 908  x1_Darkrai -0.239358
#                        name    coeff
# 604   x0_Shaymin Land Forme -1.88779
# 1387  x1_Shaymin Land Forme  1.56871
#                       name     coeff
# 605   x0_Shaymin Sky Forme  0.298702
# 1388  x1_Shaymin Sky Forme -0.373155
#           name     coeff
# 19   x0_Arceus -0.984248
# 802  x1_Arceus  0.623266
#             name     coeff
# 735   x0_Victini -0.720973
# 1518  x1_Victini  0.555093
#           name     coeff
# 640   x0_Snivy  0.865403
# 1423  x1_Snivy -0.755849
#             name      coeff
# 600   x0_Servine   0.230804
# 1383  x1_Servine -0.0948112
#               name    coeff
# 599   x0_Serperior  2.45405
# 1382  x1_Serperior -2.42183
#           name     coeff
# 689   x0_Tepig -0.712032
# 1472  x1_Tepig  0.338048
#             name    coeff
# 519   x0_Pignite  1.79118
# 1302  x1_Pignite -2.01773
#           name      coeff
# 179  x0_Emboar  -0.519944
# 962  x1_Emboar -0.0371108
#              name    coeff
# 495   x0_Oshawott  2.10085
# 1278  x1_Oshawott -2.53537
#           name     coeff
# 140  x0_Dewott -0.562465
# 923  x1_Dewott  0.731888
#              name    coeff
# 579   x0_Samurott  2.07947
# 1362  x1_Samurott  -1.8296
#            name    coeff
# 506   x0_Patrat -3.17509
# 1289  x1_Patrat  2.83166
#             name    coeff
# 751   x0_Watchog -3.15001
# 1534  x1_Watchog  2.59354
#              name    coeff
# 350   x0_Lillipup -1.38732
# 1133  x1_Lillipup  1.45978
#             name      coeff
# 276   x0_Herdier  -0.208031
# 1059  x1_Herdier -0.0763616
#               name    coeff
# 663   x0_Stoutland   1.4647
# 1446  x1_Stoutland -1.64725
#              name     coeff
# 545   x0_Purrloin  0.656943
# 1328  x1_Purrloin -0.357657
#             name    coeff
# 347   x0_Liepard  2.65576
# 1130  x1_Liepard -3.17429
#             name    coeff
# 502   x0_Pansage -2.17902
# 1285  x1_Pansage  1.80232
#              name     coeff
# 620   x0_Simisage -0.788505
# 1403  x1_Simisage    0.5799
#             name     coeff
# 503   x0_Pansear  -1.11814
# 1286  x1_Pansear  0.107655
#              name     coeff
# 621   x0_Simisear  0.429608
# 1404  x1_Simisear  -0.32574
#             name    coeff
# 501   x0_Panpour  2.03016
# 1284  x1_Panpour -2.46704
#              name     coeff
# 619   x0_Simipour  0.487047
# 1402  x1_Simipour   -0.2784
#           name    coeff
# 472   x0_Munna   1.4346
# 1255  x1_Munna -1.87223
#              name     coeff
# 474   x0_Musharna -0.952601
# 1257  x1_Musharna   1.02385
#            name     coeff
# 518   x0_Pidove  -1.23942
# 1301  x1_Pidove  0.526387
#               name    coeff
# 706   x0_Tranquill -2.35258
# 1489  x1_Tranquill  2.05585
#              name    coeff
# 721   x0_Unfezant -1.71248
# 1504  x1_Unfezant  1.07064
#            name     coeff
# 55   x0_Blitzle -0.416489
# 838  x1_Blitzle   1.48682
#               name     coeff
# 776   x0_Zebstrika -0.142275
# 1559  x1_Zebstrika  0.417142
#                name     coeff
# 572   x0_Roggenrola -0.237487
# 1355  x1_Roggenrola  0.210975
#            name     coeff
# 56   x0_Boldore  0.479412
# 839  x1_Boldore -0.182416
#              name    coeff
# 230   x0_Gigalith -1.95707
# 1013  x1_Gigalith  1.08505
#            name     coeff
# 763   x0_Woobat  0.780837
# 1546  x1_Woobat   -0.9858
#             name    coeff
# 679   x0_Swoobat -1.98621
# 1462  x1_Swoobat  1.16563
#            name    coeff
# 156  x0_Drilbur -1.82052
# 939  x1_Drilbur  1.68343
#              name    coeff
# 186  x0_Excadrill  1.81201
# 969  x1_Excadrill -1.41941
#                 name    coeff
# 402   x0_Mega Audino -1.15329
# 1185  x1_Mega Audino  1.57325
#             name    coeff
# 694   x0_Timburr  2.42742
# 1477  x1_Timburr -2.78531
#             name     coeff
# 263   x0_Gurdurr -0.891389
# 1046  x1_Gurdurr  0.876213
#               name    coeff
# 109  x0_Conkeldurr  2.21621
# 892  x1_Conkeldurr -2.24499
#             name    coeff
# 713   x0_Tympole   -1.664
# 1496  x1_Tympole  2.23855
#               name    coeff
# 498   x0_Palpitoad  1.31513
# 1281  x1_Palpitoad -1.07387
#                name    coeff
# 597   x0_Seismitoad  1.95895
# 1380  x1_Seismitoad -1.58159
#           name      coeff
# 691   x0_Throh   0.490878
# 1474  x1_Throh -0.0958109
#          name     coeff
# 583   x0_Sawk  0.884937
# 1366  x1_Sawk -0.463821
#              name    coeff
# 602   x0_Sewaddle  1.90156
# 1385  x1_Sewaddle -1.84368
#              name     coeff
# 672   x0_Swadloon -0.742174
# 1455  x1_Swadloon  0.801465
#              name    coeff
# 342   x0_Leavanny  1.59107
# 1125  x1_Leavanny -1.77559
#              name     coeff
# 729   x0_Venipede -0.512451
# 1512  x1_Venipede   1.05713
#                name     coeff
# 757   x0_Whirlipede  -1.19955
# 1540  x1_Whirlipede  0.604098
#               name     coeff
# 588   x0_Scolipede -0.598634
# 1371  x1_Scolipede  0.689593
#             name     coeff
# 112  x0_Cottonee -0.807947
# 895  x1_Cottonee   1.47266
#                name      coeff
# 756   x0_Whimsicott  -0.044282
# 1539  x1_Whimsicott  0.0869551
#             name    coeff
# 510   x0_Petilil  1.41652
# 1293  x1_Petilil -1.33911
#               name     coeff
# 349   x0_Lilligant  -2.18036
# 1132  x1_Lilligant  0.729885
#             name     coeff
# 38   x0_Basculin   -2.2085
# 821  x1_Basculin  0.897936
#             name    coeff
# 580   x0_Sandile -1.36385
# 1363  x1_Sandile  1.34225
#              name     coeff
# 325   x0_Krokorok -0.790196
# 1108  x1_Krokorok  0.709383
#                name     coeff
# 326   x0_Krookodile  0.414464
# 1109  x1_Krookodile  -0.33539
#             name    coeff
# 128  x0_Darumaka  2.28086
# 911  x1_Darumaka -2.52649
#                             name     coeff
# 126  x0_Darmanitan Standard Mode -0.634978
# 909  x1_Darmanitan Standard Mode  0.120371
#                        name     coeff
# 127  x0_Darmanitan Zen Mode  0.478755
# 910  x1_Darmanitan Zen Mode  -0.46831
#              name      coeff
# 386   x0_Maractus  0.0181432
# 1169  x1_Maractus  -0.095945
#            name    coeff
# 168  x0_Dwebble  2.27325
# 951  x1_Dwebble -1.97347
#            name     coeff
# 120  x0_Crustle  0.080742
# 903  x1_Crustle -0.315373
#             name    coeff
# 590   x0_Scraggy  2.29809
# 1373  x1_Scraggy -2.99012
#             name    coeff
# 589   x0_Scrafty -1.93295
# 1372  x1_Scrafty  1.53567
#              name     coeff
# 617   x0_Sigilyph  -1.01035
# 1400  x1_Sigilyph  0.997743
#            name     coeff
# 771   x0_Yamask -0.181295
# 1554  x1_Yamask -0.108729
#               name    coeff
# 106  x0_Cofagrigus -3.72637
# 889  x1_Cofagrigus  3.07889
#              name    coeff
# 695   x0_Tirtouga -2.60704
# 1478  x1_Tirtouga  2.64118
#               name    coeff
# 75   x0_Carracosta -2.40234
# 858  x1_Carracosta  1.71511
#           name     coeff
# 20   x0_Archen -0.773865
# 803  x1_Archen   0.95484
#             name    coeff
# 21   x0_Archeops  2.02733
# 804  x1_Archeops -1.69346
#              name    coeff
# 711   x0_Trubbish -1.42887
# 1494  x1_Trubbish  2.11202
#              name     coeff
# 221   x0_Garbodor -0.405729
# 1004  x1_Garbodor  0.454318
#           name     coeff
# 780   x0_Zorua  0.662935
# 1563  x1_Zorua -0.568735
#             name     coeff
# 779   x0_Zoroark  0.593593
# 1562  x1_Zoroark -0.393337
#              name    coeff
# 460   x0_Minccino  1.57108
# 1243  x1_Minccino -1.23988
#             name    coeff
# 96   x0_Cinccino  1.92275
# 879  x1_Cinccino -1.84467
#             name     coeff
# 250   x0_Gothita -0.632998
# 1033  x1_Gothita   0.23549
#               name     coeff
# 252   x0_Gothorita  0.144392
# 1035  x1_Gothorita -0.895609
#                name    coeff
# 251   x0_Gothitelle -1.90189
# 1034  x1_Gothitelle   1.9626
#             name    coeff
# 645   x0_Solosis -1.76312
# 1428  x1_Solosis  1.50312
#            name      coeff
# 162  x0_Duosion   -1.98763
# 945  x1_Duosion -0.0640846
#               name     coeff
# 567   x0_Reuniclus -0.274077
# 1350  x1_Reuniclus -0.351081
#             name     coeff
# 159  x0_Ducklett -0.281721
# 942  x1_Ducklett  0.402734
#            name    coeff
# 675   x0_Swanna  1.71786
# 1458  x1_Swanna  -2.1783
#               name    coeff
# 726   x0_Vanillite  -1.8911
# 1509  x1_Vanillite  1.15652
#               name     coeff
# 725   x0_Vanillish -0.397226
# 1508  x1_Vanillish  0.421197
#               name    coeff
# 727   x0_Vanilluxe -2.26344
# 1510  x1_Vanilluxe  1.93476
#             name    coeff
# 130  x0_Deerling -1.24603
# 913  x1_Deerling  1.36069
#              name    coeff
# 584   x0_Sawsbuck  1.21817
# 1367  x1_Sawsbuck -1.45383
#           name     coeff
# 180  x0_Emolga -0.705855
# 963  x1_Emolga  0.736459
#                name    coeff
# 310   x0_Karrablast -1.73126
# 1093  x1_Karrablast  1.76336
#               name     coeff
# 183  x0_Escavalier -0.663971
# 966  x1_Escavalier   1.25483
#            name    coeff
# 208  x0_Foongus  -2.4804
# 991  x1_Foongus  2.30543
#              name    coeff
# 14   x0_Amoonguss -1.88879
# 797  x1_Amoonguss  1.96337
#             name    coeff
# 211  x0_Frillish -2.99338
# 994  x1_Frillish   1.3509
#               name      coeff
# 298   x0_Jellicent    -1.2021
# 1081  x1_Jellicent -0.0441586
#              name      coeff
# 10   x0_Alomomola -0.0222052
# 793  x1_Alomomola  -0.903132
#            name     coeff
# 302   x0_Joltik -0.691189
# 1085  x1_Joltik  0.906283
#                name      coeff
# 220   x0_Galvantula  0.0279607
# 1003  x1_Galvantula   0.287121
#              name    coeff
# 196  x0_Ferroseed  1.88419
# 979  x1_Ferroseed -1.71903
#               name    coeff
# 197  x0_Ferrothorn -1.36065
# 980  x1_Ferrothorn  1.29451
#           name    coeff
# 317   x0_Klang  1.50255
# 1100  x1_Klang -2.01289
#               name    coeff
# 320   x0_Klinklang  -2.1777
# 1103  x1_Klinklang  2.50384
#            name    coeff
# 714   x0_Tynamo  2.35191
# 1497  x1_Tynamo -2.27485
#              name    coeff
# 169  x0_Eelektrik -1.46299
# 952  x1_Eelektrik  1.97852
#               name      coeff
# 170  x0_Eelektross  -0.102377
# 953  x1_Eelektross  0.0779176
#           name    coeff
# 178  x0_Elgyem  2.78879
# 961  x1_Elgyem -2.23802
#             name    coeff
# 44   x0_Beheeyem -1.47747
# 827  x1_Beheeyem  1.07807
#             name     coeff
# 353   x0_Litwick  -2.39454
# 1136  x1_Litwick -0.915137
#             name    coeff
# 332   x0_Lampent  -1.2856
# 1115  x1_Lampent -1.44394
#               name      coeff
# 81   x0_Chandelure -0.0669227
# 864  x1_Chandelure  -0.228438
#         name     coeff
# 29   x0_Axew  0.603151
# 812  x1_Axew -0.434615
#            name     coeff
# 210  x0_Fraxure -0.539026
# 993  x1_Fraxure   0.10945
#             name     coeff
# 269   x0_Haxorus -0.560589
# 1052  x1_Haxorus  0.252249
#            name     coeff
# 122  x0_Cubchoo   1.05955
# 905  x1_Cubchoo -0.899149
#            name      coeff
# 41   x0_Beartic -0.0875413
# 824  x1_Beartic    0.53674
#              name     coeff
# 121  x0_Cryogonal   1.00657
# 904  x1_Cryogonal -0.493085
#             name     coeff
# 610   x0_Shelmet -0.229139
# 1393  x1_Shelmet -0.298764
#             name    coeff
# 3    x0_Accelgor   2.3731
# 786  x1_Accelgor -2.15003
#              name    coeff
# 664   x0_Stunfisk -1.44941
# 1447  x1_Stunfisk  1.47639
#             name     coeff
# 454   x0_Mienfoo -0.531214
# 1237  x1_Mienfoo  0.269106
#              name    coeff
# 455   x0_Mienshao  1.87062
# 1238  x1_Mienshao -2.00723
#              name     coeff
# 158  x0_Druddigon -0.434594
# 941  x1_Druddigon  0.530627
#            name    coeff
# 245   x0_Golett  1.46023
# 1028  x1_Golett -1.80877
#            name    coeff
# 246   x0_Golurk  2.13222
# 1029  x1_Golurk -2.49937
#              name    coeff
# 507   x0_Pawniard  2.10577
# 1290  x1_Pawniard -2.28858
#            name    coeff
# 51   x0_Bisharp  2.52338
# 834  x1_Bisharp -2.00456
#               name   coeff
# 58   x0_Bouffalant  2.3062
# 841  x1_Bouffalant -2.2805
#             name    coeff
# 576   x0_Rufflet  2.98265
# 1359  x1_Rufflet -3.47152
#             name    coeff
# 60   x0_Braviary  2.52515
# 843  x1_Braviary -1.94815
#             name    coeff
# 744   x0_Vullaby  2.28098
# 1527  x1_Vullaby -1.51059
#               name    coeff
# 381   x0_Mandibuzz  1.03809
# 1164  x1_Mandibuzz -1.26968
#             name     coeff
# 271   x0_Heatmor   0.78181
# 1054  x1_Heatmor -0.851218
#           name    coeff
# 163  x0_Durant  2.48461
# 946  x1_Durant -2.02735
#          name    coeff
# 131  x0_Deino  2.43863
# 914  x1_Deino -1.64034
#              name    coeff
# 782   x0_Zweilous  1.50559
# 1565  x1_Zweilous -1.88135
#               name    coeff
# 291   x0_Hydreigon   1.2618
# 1074  x1_Hydreigon -1.83672
#              name    coeff
# 337   x0_Larvesta  1.31681
# 1120  x1_Larvesta -1.70122
#               name    coeff
# 742   x0_Volcarona  1.67838
# 1525  x1_Volcarona  -2.3352
#             name   coeff
# 105  x0_Cobalion  2.6051
# 888  x1_Cobalion -2.0923
#               name     coeff
# 690   x0_Terrakion  0.880709
# 1473  x1_Terrakion  -1.32874
#              name    coeff
# 739   x0_Virizion  2.66637
# 1522  x1_Virizion -2.85125
#                              name    coeff
# 701   x0_Tornadus Incarnate Forme  1.97066
# 1484  x1_Tornadus Incarnate Forme -2.36052
#                            name    coeff
# 702   x0_Tornadus Therian Forme -1.76657
# 1485  x1_Tornadus Therian Forme  1.72829
#                               name      coeff
# 692   x0_Thundurus Incarnate Forme -0.0534039
# 1475  x1_Thundurus Incarnate Forme   0.649005
#                             name     coeff
# 693   x0_Thundurus Therian Forme  0.242535
# 1476  x1_Thundurus Therian Forme  0.409923
#              name     coeff
# 566   x0_Reshiram  -1.03757
# 1349  x1_Reshiram  0.817873
#            name     coeff
# 777   x0_Zekrom  0.364684
# 1560  x1_Zekrom -0.449303
#                              name    coeff
# 333   x0_Landorus Incarnate Forme  1.85287
# 1116  x1_Landorus Incarnate Forme -2.08191
#                            name     coeff
# 334   x0_Landorus Therian Forme  0.449402
# 1117  x1_Landorus Therian Forme -0.293306
#                         name    coeff
# 329   x0_Kyurem Black Kyurem  3.08838
# 1112  x1_Kyurem Black Kyurem -2.79259
#                         name     coeff
# 330   x0_Kyurem White Kyurem -0.460549
# 1113  x1_Kyurem White Kyurem  0.681547
#                           name     coeff
# 312   x0_Keldeo Ordinary Forme  0.400728
# 1095  x1_Keldeo Ordinary Forme  -0.02886
#                           name     coeff
# 313   x0_Keldeo Resolute Forme -0.385837
# 1096  x1_Keldeo Resolute Forme  0.539255
#                         name     coeff
# 443   x0_Meloetta Aria Forme   1.19303
# 1226  x1_Meloetta Aria Forme -0.978002
#                              name    coeff
# 444   x0_Meloetta Pirouette Forme  2.35223
# 1227  x1_Meloetta Pirouette Forme -2.70787
#              name    coeff
# 226   x0_Genesect -2.84543
# 1009  x1_Genesect  2.44761
#            name    coeff
# 90   x0_Chespin -2.51749
# 873  x1_Chespin  2.78008
#               name     coeff
# 550   x0_Quilladin   1.08261
# 1333  x1_Quilladin -0.945818
#               name     coeff
# 89   x0_Chesnaught -0.561705
# 872  x1_Chesnaught   0.18229
#             name    coeff
# 194  x0_Fennekin  1.65782
# 977  x1_Fennekin -1.64476
#            name    coeff
# 59   x0_Braixen -1.59166
# 842  x1_Braixen  1.67542
#            name     coeff
# 134  x0_Delphox -0.480812
# 917  x1_Delphox  0.944684
#            name     coeff
# 212  x0_Froakie  0.902213
# 995  x1_Froakie -0.619047
#              name    coeff
# 213  x0_Frogadier -0.67198
# 996  x1_Frogadier  1.10275
#              name     coeff
# 255   x0_Greninja  0.199097
# 1038  x1_Greninja   0.28258
#             name    coeff
# 67   x0_Bunnelby -1.56876
# 850  x1_Bunnelby  1.20679
#              name     coeff
# 142  x0_Diggersby -0.623814
# 925  x1_Diggersby  0.441568
#               name    coeff
# 203  x0_Fletchling  2.17825
# 986  x1_Fletchling -2.05821
#                name     coeff
# 202  x0_Fletchinder -0.176218
# 985  x1_Fletchinder  0.266357
#                name    coeff
# 682   x0_Talonflame  1.50562
# 1465  x1_Talonflame  -1.8223
#                name    coeff
# 585   x0_Scatterbug  1.26001
# 1368  x1_Scatterbug -1.71907
#            name     coeff
# 648   x0_Spewpa  -2.61296
# 1431  x1_Spewpa -0.495911
#              name     coeff
# 740   x0_Vivillon  -1.41848
# 1523  x1_Vivillon -0.469779
#            name    coeff
# 352   x0_Litleo -1.50926
# 1135  x1_Litleo -1.30392
#            name    coeff
# 547   x0_Pyroar -1.03948
# 1330  x1_Pyroar -1.43762
#              name    coeff
# 200  x0_FlabÃ©bÃ© -3.35633
# 983  x1_FlabÃ©bÃ©  2.45854
#            name    coeff
# 205  x0_Floette -2.23814
# 988  x1_Floette  1.14026
#            name    coeff
# 206  x0_Florges -0.81617
# 989  x1_Florges  1.14596
#            name     coeff
# 623   x0_Skiddo  0.322257
# 1406  x1_Skiddo -0.561491
#            name     coeff
# 240   x0_Gogoat  -1.46696
# 1023  x1_Gogoat  0.833517
#             name     coeff
# 499   x0_Pancham   1.03008
# 1282  x1_Pancham -0.536455
#             name    coeff
# 500   x0_Pangoro -1.17199
# 1283  x1_Pangoro  1.30264
#            name      coeff
# 216  x0_Furfrou  0.0602878
# 999  x1_Furfrou  0.0712158
#           name    coeff
# 185  x0_Espurr -2.52283
# 968  x1_Espurr  2.11288
#                   name    coeff
# 446   x0_Meowstic Male -1.31144
# 1229  x1_Meowstic Male  2.14373
#                     name    coeff
# 445   x0_Meowstic Female -1.63565
# 1228  x1_Meowstic Female  2.21714
#             name     coeff
# 284   x0_Honedge -0.367079
# 1067  x1_Honedge  0.619214
#             name     coeff
# 148  x0_Doublade  0.283029
# 931  x1_Doublade -0.252207
#                          name    coeff
# 4    x0_Aegislash Blade Forme  1.95015
# 787  x1_Aegislash Blade Forme -1.23422
#                           name    coeff
# 5    x0_Aegislash Shield Forme -1.18736
# 788  x1_Aegislash Shield Forme  1.20412
#              name     coeff
# 654   x0_Spritzee  0.412789
# 1437  x1_Spritzee  -0.23208
#               name    coeff
# 24   x0_Aromatisse -1.52706
# 807  x1_Aromatisse  1.75823
#             name     coeff
# 678   x0_Swirlix -0.523447
# 1461  x1_Swirlix  0.443185
#              name      coeff
# 636   x0_Slurpuff  -0.783185
# 1419  x1_Slurpuff -0.0395362
#           name    coeff
# 296   x0_Inkay  2.30413
# 1079  x1_Inkay -1.80856
#             name    coeff
# 378   x0_Malamar  2.30156
# 1161  x1_Malamar  -2.2281
#            name    coeff
# 50   x0_Binacle -1.70418
# 833  x1_Binacle  1.12642
#               name    coeff
# 36   x0_Barbaracle -1.90386
# 819  x1_Barbaracle  1.67757
#            name     coeff
# 627   x0_Skrelp -0.403398
# 1410  x1_Skrelp  0.183855
#             name     coeff
# 149  x0_Dragalge  0.755437
# 932  x1_Dragalge -0.398784
#              name      coeff
# 98   x0_Clauncher    1.05642
# 881  x1_Clauncher -0.0893885
#              name    coeff
# 99   x0_Clawitzer -1.68174
# 882  x1_Clawitzer   1.5424
#                name     coeff
# 274   x0_Helioptile -0.782648
# 1057  x1_Helioptile  0.595866
#               name     coeff
# 273   x0_Heliolisk -0.471802
# 1056  x1_Heliolisk  0.143409
#            name     coeff
# 719   x0_Tyrunt  -1.07084
# 1502  x1_Tyrunt  0.375896
#               name     coeff
# 717   x0_Tyrantrum   -1.3631
# 1500  x1_Tyrantrum  0.981396
#           name    coeff
# 12   x0_Amaura  1.30896
# 795  x1_Amaura -1.05302
#            name    coeff
# 28   x0_Aurorus   1.6158
# 811  x1_Aurorus -1.96199
#             name     coeff
# 680   x0_Sylveon  0.199438
# 1463  x1_Sylveon -0.906769
#              name     coeff
# 268   x0_Hawlucha -0.331966
# 1051  x1_Hawlucha  0.782856
#            name    coeff
# 129  x0_Dedenne -2.69163
# 912  x1_Dedenne  2.52393
#            name    coeff
# 73   x0_Carbink -1.03443
# 856  x1_Carbink  0.95128
#           name    coeff
# 248   x0_Goomy -0.82806
# 1031  x1_Goomy  1.38298
#             name    coeff
# 631   x0_Sliggoo  3.12757
# 1414  x1_Sliggoo -1.97711
#            name    coeff
# 247   x0_Goodra  1.96026
# 1030  x1_Goodra -2.27638
#            name    coeff
# 318   x0_Klefki  1.92897
# 1101  x1_Klefki -1.95992
#              name    coeff
# 512   x0_Phantump  1.39599
# 1295  x1_Phantump -1.54005
#               name     coeff
# 709   x0_Trevenant -0.844246
# 1492  x1_Trevenant   0.89344
#                            name    coeff
# 540   x0_Pumpkaboo Average Size  2.73186
# 1323  x1_Pumpkaboo Average Size -2.38055
#                          name    coeff
# 542   x0_Pumpkaboo Small Size -1.40283
# 1325  x1_Pumpkaboo Small Size -1.47561
#                          name     coeff
# 541   x0_Pumpkaboo Large Size  0.365222
# 1324  x1_Pumpkaboo Large Size -0.881812
#                          name     coeff
# 543   x0_Pumpkaboo Super Size  0.398226
# 1326  x1_Pumpkaboo Super Size -0.421508

# %%
plt.plot(Diff)

# %% [markdown]
# not always the same, maybe first and second have some meaning

# %%
#predict some outcome of fights

# %%
corresp.loc[corresp.name.str.contains("Golbat")]
# Out:
#            name     coeff
# 241   x0_Golbat  -1.34279
# 1024  x1_Golbat  0.484885

# %%
corresp.loc[corresp.name.str.contains("Kakuna")]
# Out:
#            name     coeff
# 308   x0_Kakuna  0.479622
# 1091  x1_Kakuna -0.406972

# %%
def sigmoid(x):
    return (1 / (1 + np.exp(-x)))

# %%
sigmoid(-1.34 -0.4)
# Out:
# 0.1493129345308437

# %%
LogReg.predict(oneh.transform(np.array(["Yanma","Shroomish"]).reshape(1,-1)))
# Out:
# array([0])
